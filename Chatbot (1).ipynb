# %% [markdown]
# Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import string
import nltk
import random
import json

# %% [markdown]
# Importing the dataset

# %%
f = open('dialogs.txt','r', errors = 'ignore')
doc = f.read()

# %% [markdown]
# Tokenization

# %%
doc = doc.lower()
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
sentence_tokens = nltk.sent_tokenize(doc)
word_tokens = nltk.word_tokenize(doc)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
sentence_tokens[2]
# Out:
# 'how about yourself?'

# %%
word_tokens[:4]
# Out:
# ['hi', ',', 'how', 'are']

# %% [markdown]
# Stop word removal

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(doc)
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
filtered_sentence = []

for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

print(word_tokens)
print(filtered_sentence)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['hi', ',', 'how', 'are', 'you', 'doing', '?', 'i', "'m", 'fine', '.', 'how', 'about', 'yourself', '?', 'i', "'m", 'fine', '.', 'how', 'about', 'yourself', '?', 'i', "'m", 'pretty', 'good', '.', 'thanks', 'for', 'asking', '.', 'i', "'m", 'pretty', 'good', '.', 'thanks', 'for', 'asking', '.', 'no', 'problem', '.', 'so', 'how', 'have', 'you', 'been', '?', 'no', 'problem', '.', 'so', 'how', 'have', 'you', 'been', '?', 'i', "'ve", 'been', 'great', '.', 'what', 'about', 'you', '?', 'i', "'ve", 'been', 'great', '.', 'what', 'about', 'you', '?', 'i', "'ve", 'been', 'good', '.', 'i', "'m", 'in', 'school', 'right', 'now', '.', 'i', "'ve", 'been', 'good', '.', 'i', "'m", 'in', 'school', 'right', 'now', '.', 'what', 'school', 'do', 'you', 'go', 'to', '?', 'what', 'school', 'do', 'you', 'go', 'to', '?', 'i', 'go', 'to', 'pcc', '.', 'i', 'go', 'to', 'pcc', '.', 'do', 'you', 'like', 'it', 'there', '?', 'do', 'you', 'like', 'it', 'there', '?', 'it', "'s", 'okay', '.', 'it', "'s", 'a', 'really', 'big', 'campus', '.', 'it', "'s", 'okay', '.', 'it', "'s", 'a', 'really', 'big', 'campus', '.', 'good', 'luck', 'with', 'school', '.', 'good', 'luck', 'with', 'school', '.', 'thank', 'you', 'very', 'much', '.', 'how', "'s", 'it', 'going', '?', 'i', "'m", 'doing', 'well', '.', 'how', 'about', 'you', '?', 'i', "'m", 'doing', 'well', '.', 'how', 'about', 'you', '?', 'never', 'better', ',', 'thanks', '.', 'never', 'better', ',', 'thanks', '.', 'so', 'how', 'have', 'you', 'been', 'lately', '?', 'so', 'how', 'have', 'you', 'been', 'lately', '?', 'i', "'ve", 'actually', 'been', 'pretty', 'good', '.', 'you', '?', 'i', "'ve", 'actually', 'been', 'pretty', 'good', '.', 'you', '?', 'i', "'m", 'actually', 'in', 'school', 'right', 'now', '.', 'i', "'m", 'actually', 'in', 'school', 'right', 'now', '.', 'which', 'school', 'do', 'you', 'attend', '?', 'which', 'school', 'do', 'you', 'attend', '?', 'i', "'m", 'attending', 'pcc', 'right', 'now', '.', 'i', "'m", 'attending', 'pcc', 'right', 'now', '.', 'are', 'you', 'enjoying', 'it', 'there', '?', 'are', 'you', 'enjoying', 'it', 'there', '?', 'it', "'s", 'not', 'bad', '.', 'there', 'are', 'a', 'lot', 'of', 'people', 'there', '.', 'it', "'s", 'not', 'bad', '.', 'there', 'are', 'a', 'lot', 'of', 'people', 'there', '.', 'good', 'luck', 'with', 'that', '.', 'good', 'luck', 'with', 'that', '.', 'thanks', '.', 'how', 'are', 'you', 'doing', 'today', '?', 'i', "'m", 'doing', 'great', '.', 'what', 'about', 'you', '?', 'i', "'m", 'doing', 'great', '.', 'what', 'about', 'you', '?', 'i', "'m", 'absolutely', 'lovely', ',', 'thank', 'you', '.', 'i', "'m", 'absolutely', 'lovely', ',', 'thank', 'you', '.', 'everything', "'s", 'been', 'good', 'with', 'you', '?', 'everything', "'s", 'been', 'good', 'with', 'you', '?', 'i', 'have', "n't", 'been', 'better', '.', 'how', 'about', 'yourself', '?', 'i', 'have', "n't", 'been', 'better', '.', 'how', 'about', 'yourself', '?', 'i', 'started', 'school', 'recently', '.', 'i', 'started', 'school', 'recently', '.', 'where', 'are', 'you', 'going', 'to', 'school', '?', 'where', 'are', 'you', 'going', 'to', 'school', '?', 'i', "'m", 'going', 'to', 'pcc', '.', 'i', "'m", 'going', 'to', 'pcc', '.', 'how', 'do', 'you', 'like', 'it', 'so', 'far', '?', 'how', 'do', 'you', 'like', 'it', 'so', 'far', '?', 'i', 'like', 'it', 'so', 'far', '.', 'my', 'classes', 'are', 'pretty', 'good', 'right', 'now', '.', 'i', 'like', 'it', 'so', 'far', '.', 'my', 'classes', 'are', 'pretty', 'good', 'right', 'now', '.', 'i', 'wish', 'you', 'luck', '.', 'it', "'s", 'an', 'ugly', 'day', 'today', '.', 'i', 'know', '.', 'i', 'think', 'it', 'may', 'rain', '.', 'i', 'know', '.', 'i', 'think', 'it', 'may', 'rain', '.', 'it', "'s", 'the', 'middle', 'of', 'summer', ',', 'it', 'should', "n't", 'rain', 'today', '.', 'it', "'s", 'the', 'middle', 'of', 'summer', ',', 'it', 'should', "n't", 'rain', 'today', '.', 'that', 'would', 'be', 'weird', '.', 'that', 'would', 'be', 'weird', '.', 'yeah', ',', 'especially', 'since', 'it', "'s", 'ninety', 'd ...
# ['hi', ',', '?', "'m", 'fine', '.', '?', "'m", 'fine', '.', '?', "'m", 'pretty', 'good', '.', 'thanks', 'asking', '.', "'m", 'pretty', 'good', '.', 'thanks', 'asking', '.', 'problem', '.', '?', 'problem', '.', '?', "'ve", 'great', '.', '?', "'ve", 'great', '.', '?', "'ve", 'good', '.', "'m", 'school', 'right', '.', "'ve", 'good', '.', "'m", 'school', 'right', '.', 'school', 'go', '?', 'school', 'go', '?', 'go', 'pcc', '.', 'go', 'pcc', '.', 'like', '?', 'like', '?', "'s", 'okay', '.', "'s", 'really', 'big', 'campus', '.', "'s", 'okay', '.', "'s", 'really', 'big', 'campus', '.', 'good', 'luck', 'school', '.', 'good', 'luck', 'school', '.', 'thank', 'much', '.', "'s", 'going', '?', "'m", 'well', '.', '?', "'m", 'well', '.', '?', 'never', 'better', ',', 'thanks', '.', 'never', 'better', ',', 'thanks', '.', 'lately', '?', 'lately', '?', "'ve", 'actually', 'pretty', 'good', '.', '?', "'ve", 'actually', 'pretty', 'good', '.', '?', "'m", 'actually', 'school', 'right', '.', "'m", 'actually', 'school', 'right', '.', 'school', 'attend', '?', 'school', 'attend', '?', "'m", 'attending', 'pcc', 'right', '.', "'m", 'attending', 'pcc', 'right', '.', 'enjoying', '?', 'enjoying', '?', "'s", 'bad', '.', 'lot', 'people', '.', "'s", 'bad', '.', 'lot', 'people', '.', 'good', 'luck', '.', 'good', 'luck', '.', 'thanks', '.', 'today', '?', "'m", 'great', '.', '?', "'m", 'great', '.', '?', "'m", 'absolutely', 'lovely', ',', 'thank', '.', "'m", 'absolutely', 'lovely', ',', 'thank', '.', 'everything', "'s", 'good', '?', 'everything', "'s", 'good', '?', "n't", 'better', '.', '?', "n't", 'better', '.', '?', 'started', 'school', 'recently', '.', 'started', 'school', 'recently', '.', 'going', 'school', '?', 'going', 'school', '?', "'m", 'going', 'pcc', '.', "'m", 'going', 'pcc', '.', 'like', 'far', '?', 'like', 'far', '?', 'like', 'far', '.', 'classes', 'pretty', 'good', 'right', '.', 'like', 'far', '.', 'classes', 'pretty', 'good', 'right', '.', 'wish', 'luck', '.', "'s", 'ugly', 'day', 'today', '.', 'know', '.', 'think', 'may', 'rain', '.', 'know', '.', 'think', 'may', 'rain', '.', "'s", 'middle', 'summer', ',', "n't", 'rain', 'today', '.', "'s", 'middle', 'summer', ',', "n't", 'rain', 'today', '.', 'would', 'weird', '.', 'would', 'weird', '.', 'yeah', ',', 'especially', 'since', "'s", 'ninety', 'degrees', 'outside', '.', 'yeah', ',', 'especially', 'since', "'s", 'ninety', 'degrees', 'outside', '.', 'know', ',', 'would', 'horrible', 'rained', 'hot', 'outside', '.', 'know', ',', 'would', 'horrible', 'rained', 'hot', 'outside', '.', 'yes', ',', 'would', '.', 'yes', ',', 'would', '.', 'really', 'wish', "n't", 'hot', 'every', 'day', '.', 'really', 'wish', "n't", 'hot', 'every', 'day', '.', '.', 'ca', "n't", 'wait', 'winter', '.', '.', 'ca', "n't", 'wait', 'winter', '.', 'like', 'winter', ',', 'sometimes', 'gets', 'cold', '.', 'like', 'winter', ',', 'sometimes', 'gets', 'cold', '.', "'d", 'rather', 'cold', 'hot', '.', "'d", 'rather', 'cold', 'hot', '.', '.', "n't", 'look', 'nice', 'outside', 'today', '.', "'re", 'right', '.', 'think', "'s", 'going', 'rain', 'later', '.', "'re", 'right', '.', 'think', "'s", 'going', 'rain', 'later', '.', 'middle', 'summer', ',', "n't", 'raining', '.', 'middle', 'summer', ',', "n't", 'raining', '.', 'would', "n't", 'seem', 'right', '.', 'would', "n't", 'seem', 'right', '.', 'considering', "'s", 'ninety', 'degrees', 'outside', ',', 'would', 'weird', '.', 'considering', "'s", 'ninety', 'degrees', 'outside', ',', 'would', 'weird', '.', 'exactly', ',', 'would', "n't", 'nice', 'started', 'raining', '.', "'s", 'hot', '.', 'exactly', ',', 'would', "n't", 'nice', 'started', 'raining', '.', "'s", 'hot', '.', 'know', ',', "'re", 'absolutely', 'right', '.', 'know', ',', "'re", 'absolutely', 'right', '.', 'wish', 'would', 'cool', 'one', 'day', '.', 'wish', 'would', 'cool', 'one', 'day', '.', "'s", 'feel', ',', 'want', 'winter', 'come', 'soon', '.', "'s", 'feel', ',', 'want', 'winter', 'come', 'soon', '.', 'enjoy', 'winter', ',', 'gets', 're ...

# %% [markdown]
# Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
words=[]
classes=[]
documents=[]
ignore=['?','!',',',"'s"]

data_file=open('Intent.json').read()
intents=json.loads(data_file)

# %% [markdown]
# Part-of-Speech tagging

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp(doc)
for token in doc:
    print(token.text, token.pos_)
# Out:
# Streaming output truncated to the last 5000 lines.
# soldiers NOUN
# were AUX
# killed VERB
# overseas ADV
# . PUNCT
# 	 SPACE
# not PART
# to PART
# mention VERB
# 40,000 NUM
# wounded ADJ
# soldiers NOUN
# . PUNCT
#
#  SPACE
# not PART
# to PART
# mention VERB
# 40,000 NUM
# wounded ADJ
# soldiers NOUN
# . PUNCT
# 	 SPACE
# but CCONJ
# bush PROPN
# visited VERB
# some PRON
# of ADP
# them PRON
# in ADP
# the DET
# hospital NOUN
# once ADV
# . PUNCT
#
#  SPACE
# but CCONJ
# bush PROPN
# visited VERB
# some PRON
# of ADP
# them PRON
# in ADP
# the DET
# hospital NOUN
# once ADV
# . PUNCT
# 	 SPACE
# that PRON
# 's AUX
# nice ADJ
# that SCONJ
# he PRON
# found VERB
# the DET
# time NOUN
# to PART
# make VERB
# a DET
# visit NOUN
# . PUNCT
#
#  SPACE
# that PRON
# 's AUX
# nice ADJ
# that SCONJ
# he PRON
# found VERB
# the DET
# time NOUN
# to PART
# make VERB
# a DET
# visit NOUN
# . PUNCT
# 	 SPACE
# he PRON
# spoke VERB
# to ADP
# them PRON
# and CCONJ
# made VERB
# them PRON
# feel VERB
# better ADJ
# . PUNCT
#
#  SPACE
# he PRON
# spoke VERB
# to ADP
# them PRON
# and CCONJ
# made VERB
# them PRON
# feel VERB
# better ADJ
# . PUNCT
# 	 SPACE
# did AUX
# he PRON
# speak VERB
# to ADP
# every DET
# family NOUN
# that PRON
# lost VERB
# a DET
# soldier NOUN
# ? PUNCT
#
#  SPACE
# did AUX
# he PRON
# speak VERB
# to ADP
# every DET
# family NOUN
# that PRON
# lost VERB
# a DET
# soldier NOUN
# ? PUNCT
# 	 SPACE
# no INTJ
# , PUNCT
# he PRON
# did AUX
# n't PART
# have VERB
# time NOUN
# to PART
# do VERB
# that PRON
# . PUNCT
#
#  SPACE
# no INTJ
# , PUNCT
# he PRON
# did AUX
# n't PART
# have VERB
# time NOUN
# to PART
# do VERB
# that PRON
# . PUNCT
# 	 SPACE
# well ADV
# , PUNCT
# he PRON
# 's AUX
# got VERB
# plenty NOUN
# of ADP
# time NOUN
# now ADV
# ! PUNCT
#
#  SPACE
# well ADV
# , PUNCT
# he PRON
# 's AUX
# got VERB
# plenty NOUN
# of ADP
# time NOUN
# now ADV
# ! PUNCT
# 	 SPACE
# no INTJ
# , PUNCT
# he PRON
# 's AUX
# too ADV
# busy ADJ
# writing VERB
# a DET
# book NOUN
# about ADP
# how SCONJ
# hard ADJ
# it PRON
# was AUX
# to PART
# be AUX
# president NOUN
# . PUNCT
#
#  SPACE
# did AUX
# you PRON
# get VERB
# your PRON
# official ADJ
# sample NOUN
# ballot NOUN
# ? PUNCT
# 	 SPACE
# yes INTJ
# , PUNCT
# with ADP
# the DET
# voter NOUN
# instructions NOUN
# . PUNCT
#
#  SPACE
# yes INTJ
# , PUNCT
# with ADP
# the DET
# voter NOUN
# instructions NOUN
# . PUNCT
# 	 SPACE
# how SCONJ
# are AUX
# you PRON
# going VERB
# to PART
# vote VERB
# ? PUNCT
#
#  SPACE
# how SCONJ
# are AUX
# you PRON
# going VERB
# to PART
# vote VERB
# ? PUNCT
# 	 SPACE
# same ADJ
# as ADP
# ever ADV
# , PUNCT
# by ADP
# mail NOUN
# . PUNCT
# all PRON
# it PRON
# costs VERB
# me PRON
# is AUX
# a DET
# 42 NUM
# - PUNCT
# cent NOUN
# stamp NOUN
# . PUNCT
#
#  SPACE
# same ADJ
# as ADP
# ever ADV
# , PUNCT
# by ADP
# mail NOUN
# . PUNCT
# all PRON
# it PRON
# costs VERB
# me PRON
# is AUX
# a DET
# 42 NUM
# - PUNCT
# cent NOUN
# stamp NOUN
# . PUNCT
# 	 SPACE
# i PRON
# meant VERB
# , PUNCT
# are AUX
# you PRON
# going VERB
# to PART
# vote VERB
# for ADP
# or CCONJ
# against ADP
# the DET
# new ADJ
# taxes NOUN
# ? PUNCT
#
#  SPACE
# i PRON
# meant VERB
# , PUNCT
# are AUX
# you PRON
# going VERB
# to PART
# vote VERB
# for ADP
# or CCONJ
# against ADP
# the DET
# new ADJ
# taxes NOUN
# ? PUNCT
# 	 SPACE
# against ADP
# all PRON
# of ADP
# them PRON
# , PUNCT
# of ADP
# course NOUN
# . PUNCT
#
#  SPACE
# against ADP
# all PRON
# of ADP
# them PRON
# , PUNCT
# of ADP
# course NOUN
# . PUNCT
# 	 SPACE
# but CCONJ
# we PRON
# need VERB
# new ADJ
# taxes NOUN
# to PART
# pay VERB
# for ADP
# highways NOUN
# , PUNCT
# schools NOUN
# , PUNCT
# and CCONJ
# prisons NOUN
# . PUNCT
#
#  SPACE
# but CCONJ
# we PRON
# need VERB
# new ADJ
# taxes NOUN
# to PART
# pay VERB
# for ADP
# highways NOUN
# , PUNCT
# schools NOUN
# , PUNCT
# and CCONJ
# prisons NOUN
# . PUNCT
# 	 SPACE
# we PRON
# 've AUX
# already ADV
# voted VERB
# for ADP
# new ADJ
# taxes NOUN
# to PART
# pay VERB
# for ADP
# all DET
# that DET
# stuff NOUN
# ! PUNCT
#
#  SPACE
# we PRON
# 've AUX
# already ADV
# voted VERB
# for ADP
# new ADJ
# taxes NOUN
# to PART
# pay VERB
# for ADP
# all DET
# that DET
# stuff NOUN
# ! PUNCT
# 	 SPACE
# that PRON
# 's AUX
# true ADJ
# . PUNCT
# where SCONJ
# did AUX
# that DET
# money NOUN
# go VERB
# ? PUNCT
#
#  SPACE
# that PRON
# 's AUX
# true ADJ
# . PUNCT
# where SCONJ
# did AUX
# that DET
# money NOUN
# go VERB
# ? PUNCT
# 	 SPACE
# our PRON
# legislators NOUN
# spent VERB
# it PRON
# on ADP
# first ADJ
# - PUNCT
# class NOUN
# travel NOUN
# all ADV
# over ADP
# the DET
# world NOUN
# . PUNCT
#
#  SPACE
# our PRON
# legislators NOUN
# spent VERB
# it PRON
# on ADP
# first ADJ
# - PUNCT
# class NOUN
# travel NOUN
# all ADV
# over ADP
# the DET
# world NOUN
# . PUNCT
# 	 SPACE
# they PRON
# are AUX
# having VERB
# a DET
# good ADJ
# time NOUN
# with ADP
# our PRON
# money NOUN
# . PUNCT
#
#  SPACE
# they PRON
# are AUX
# having VERB
# a DET
# good ADJ
# time NOUN
# with ADP
# our PRON
# money NOUN
# . PUNCT
# 	 SPACE
# so ADV
# when SCONJ
# are AUX
# we PRON
# going VERB
# to PART
# stop VERB
# giving VERB
# them PRON
# more ADV
# ? PUNCT
#
#  SPACE
# have AUX
# you PRON
# decided VERB
# how SCONJ
# you PRON
# are AUX
# going VERB
# to PART
# vote VERB
# ? PUNCT
# 	 SPACE
# do AUX
# you PRON
# mean VERB
# on ADP
# measures NOUN
# 1 NUM
# , PUNCT
# 2 NUM
# , PUNCT
# and CCONJ
# 3 NUM
# ? PUNCT
#
#  SPACE
# do AUX
# you PRON
# mean VERB
# on ADP
# measures NOUN
# 1 NUM
# , PUNCT
# 2 NUM
# , PUNCT
# and CCONJ
# 3 NUM
# ? NOUN
# 	 SPACE
# yes INTJ
# . PUNCT
# the DET
# ones NOUN
# that PRON
# will AUX
# improve VERB
# our PRON
# schools NOUN
# , PUNCT
# roads NOUN
# , PUNCT
# and CCONJ
# hospitals NOUN
# . PUNCT
#
#  SPACE
# yes INTJ
# . PUNCT
# the DET
# ones NOUN
# that PRON
# will AUX
# improve VERB
# our PRON
# schools NOUN
# , PUNCT
# roads NOUN
# , PUNCT
# and CCONJ
# hospitals NOUN
# . PUNCT
# 	 SPACE
# you PRON
# mean VERB
# the DET
# measures NOUN
# that PRON
# will AUX
# raise VERB
# our PRON
# taxes NOUN
# . PUNCT
#
#  SPACE
# you PRON
# mean VERB
# the DET
# measures NOUN
# that PRON
# will AUX
# raise VERB
# our PRON
# taxes NOUN
# . PUNCT
# 	 SPACE
# but CCONJ
# the DET
# tv NOUN
# ads NOUN
# say VERB
# that SCONJ
# our PRON
# taxes NOUN
# will AUX
# not PART
# increase VERB
# . PUNCT
#
#  SPACE
# but CCONJ
# the DET
# tv NOUN
# ads NOUN
# say VERB
# that SCONJ
# our PRON
# taxes NOUN
# will AUX
# not PART
# increase VERB
# . PUNCT
# 	 SPACE
# do AUX
# you PRON
# believe VERB
# the DET
# tv NOUN
# ads NOUN
# ? PUNCT
#
#  SPACE
# do AUX
# you PRON
# believe VERB
# the DET
# tv NOUN
# ads NOUN
# ? PUNCT
# 	 SPACE
# i PRON
# like VERB
# the DET
# one NOUN
# where SCONJ
# the DET
# fireman NOUN
# tells VERB
# us PRON
# why SCONJ
# we PRON
# should AUX
# vote VERB
# yes INTJ
# . PUNCT
#
#  SPACE
# i PRON
# like VERB
# the DET
# one NOUN
# where SCONJ
# the DET
# fireman NOUN
# tells VERB
# us PRON
# why SCONJ
# we PRON
# should AUX
# vote VERB
# yes INTJ
# . PUNCT
# 	 SPACE
# do AUX
# n't PART
# believe VERB
# him PRON
# ! PUNCT
# whatever PRON
# the DET
# tv NOUN
# ads NOUN
# tell VERB
# you PRON
# , PUNCT
# the DET
# opposite NOUN
# is AUX
# true ADJ
# . PUNCT
#
#  SPACE
# do AUX
# n't PART
# believe VERB
# him PRON
# ! PUNCT
# whatever PRON
# the DET
# tv NOUN
# ads NOUN
# tell VERB
# you PRON
# , PUNCT
# the DET
# opposite NOUN
# is AUX
# true ADJ
# . PUNCT
# 	 SPACE
# but CCONJ
# the DET
# title NOUN
# of ADP
# measure NOUN
# 1 NUM
# is AUX
# " PUNCT
# better ADJ
# schools NOUN
# at ADP
# no DET
# cost NOUN
# . PUNCT
# " PUNCT
#
#  SPACE
# but CCONJ
# the DET
# title NOUN
# of ADP
# measure NOUN
# 1 NUM
# is AUX
# " PUNCT
# better ADJ
# schools NOUN
# at ADP
# no DET
# cost NOUN
# . PUNCT
# " PUNCT
# 	 SPACE
# the DET
# title NOUN
# should AUX
# be AUX
# " PUNCT
# better ADJ
# schools NOUN
# at ADP
# huge ADJ
# cost NOUN
# . PUNCT
# " PUNCT
#
#  SPACE
# the DET
# title NOUN
# should AUX
# be AUX
# " PUNCT
# better ADJ
# schools NOUN
# at ADP
# huge ADJ
# cost NOUN
# . PUNCT
# " PUNCT
# 	 SPACE
# i PRON
# ca AUX
# n't PART
# believe VERB
# that SCONJ
# they PRON
# would AUX
# lie VERB
# to ADP
# us PRON
# . PUNCT
#
#  SPACE
# i PRON
# ca AUX
# n't PART
# believe VERB
# that SCONJ
# they PRON
# would AUX
# lie VERB
# to ADP
# us PRON
# . PUNCT
# 	 SPACE
# of ADV
# course ADV
# they PRON
# liethat PROPN
# 's AUX
# what PRON
# politicians NOUN
# do VERB
# ! PUNCT
#
#  SPACE
# i PRON
# have VERB
# a DET
# stomachache NOUN
# . PUNCT
# 	 SPACE
# is AUX
# it PRON
# something PRON
# you PRON
# ate VERB
# ? PUNCT
#
#  SPACE
# is AUX
# it PRON
# something PRON
# you PRON
# ate VERB
# ? PUNCT
# 	 SPACE
# maybe ADV
# . PUNCT
# i PRON
# 'm AUX
# not PART
# sure ADJ
# . PUNCT
#
#  SPACE
# maybe ADV
# . PUNCT
# i PRON
# 'm AUX
# not PART
# sure ADJ
# . PUNCT
# 	 SPACE
# what PRON
# did AUX
# you PRON
# have VERB
# for ADP
# breakfast NOUN
# ? PUNCT
#
#  SPACE
# what PRON
# did AUX
# you PRON
# have VERB
# for ADP
# breakfast NOUN
# ? PUNCT
# 	 SPACE
# the DET
# usual ADJ
# , PUNCT
# cereal NOUN
# with ADP
# milk NOUN
# and CCONJ
# a DET
# banana NOUN
# . PUNCT
#
#  SPACE
# the DET
# usual ADJ
# , PUNCT
# cereal NOUN
# with ADP
# milk NOUN
# and CCONJ
# a DET
# banana NOUN
# . PUNCT
# 	 SPACE
# maybe ADV
# the DET
# milk NOUN
# was AUX
# bad ADJ
# . PUNCT
#
#  SPACE
# maybe ADV
# the DET
# milk NOUN
# was AUX
# bad ADJ
# . PUNCT
# 	 SPACE
# it PRON
# did AUX
# n't PART
# smell VERB
# bad ADJ
# . PUNCT
#
#  SPACE
# it PRON
# did AUX
# n't PART
# smell VERB
# bad ADJ
# . PUNCT
# 	 SPACE
# maybe ADV
# the DET
# banana NOUN
# was AUX
# bad ADJ
# . PUNCT
#
#  SPACE
# maybe ADV
# the DET
# banana NOUN
# was AUX
# bad ADJ
# . PUNCT
# 	 SPACE
# no INTJ
# , PUNCT
# the DET
# banana NOUN
# was AUX
# delicious ADJ
# . PUNCT
#
#  SPACE
# no INTJ
# , PUNCT
# the DET
# banana NOUN
# was AUX
# delicious ADJ
# . PUNCT
# 	 SPACE
# maybe ADV
# you PRON
# just ADV
# need VERB
# to PART
# go VERB
# to ADP
# the DET
# bathroom NOUN
# . PUNCT
#
#  SPACE
# maybe ADV
# you PRON
# just ADV
# need VERB
# to PART
# go VERB
# to ADP
# the DET
# bathroom NOUN
# . PUNCT
# 	 SPACE
# no INTJ
# , PUNCT
# that PRON
# 's AUX
# not PART
# the DET
# problem NOUN
# . PUNCT
#
#  SPACE
# no INTJ
# , PUNCT
# that PRON
# 's AUX
# not PART
# the DET
# problem NOUN
# . PUNCT
# 	 SPACE
# maybe ADV
# it PRON
# will AUX
# go VERB
# away ADV
# in ADP
# a DET
# little ADJ
# while NOUN
# . PUNCT
#
#  SPACE
# what PRON
# 's AUX
# this DET
# stain NOUN
# ? PUNCT
# 	 SPACE
# i PRON
# do AUX
# n't PART
# know VERB
# . PUNCT
#
#  SPACE
# i PRON
# do AUX
# n't PART
# know VERB
# . PUNCT
# 	 SPACE
# it PRON
# looks VERB
# like ADP
# blood NOUN
# . PUNCT
#
#  SPACE
# it PRON
# looks VERB
# like ADP
# blood NOUN
# . PUNCT
# 	 SPACE
# i PRON
# think VERB
# my PRON
# nose NOUN
# was AUX
# bleeding VERB
# . PUNCT
#
#  SPACE
# i PRON
# think VERB
# my PRON
# nose NOUN
# was AUX
# bleeding VERB
# . PUNCT
# 	 SPACE
# you PRON
# should AUX
# wet VERB
# your PRON
# shirt NOUN
# immediately ADV
# . PUNCT
#
#  SPACE
# you PRON
# should AUX
# wet VERB
# your PRON
# shirt NOUN
# immediately ADV
# . PUNCT
# 	 SPACE
# why SCONJ
# ? PUNCT
#
#  SPACE
# why SCONJ
# ? PUNCT
# 	 SPACE
# because SCONJ
# that PRON
# gets VERB
# the DET
# blood NOUN
# out ADP
# of ADP
# the DET
# shirt NOUN
# . PUNCT
#
#  SPACE
# because SCONJ
# that PRON
# gets VERB
# the DET
# blood NOUN
# out ADP
# of ADP
# the DET
# shirt NOUN
# . PUNCT
# 	 SPACE
# what PRON
# 's AUX
# a DET
# little ADJ
# blood NOUN
# ? PUNCT
#
#  SPACE
# what PRON
# 's AUX
# a DET
# little ADJ
# blood NOUN
# ? PUNCT
# 	 SPACE
# your PRON
# white ADJ
# shirt NOUN
# is AUX
# ruined VERB
# . PUNCT
#
#  SPACE
# your PRON
# white ADJ
# shirt NOUN
# is AUX
# ruined VERB
# . PUNCT
# 	 SPACE
# so ADV
# , PUNCT
# i PRON
# 'll AUX
# just ADV
# buy VERB
# another DET
# one NOUN
# . PUNCT
#
#  SPACE
# so ADV
# , PUNCT
# i PRON
# 'll AUX
# just ADV
# buy VERB
# another DET
# one NOUN
# . PUNCT
# 	 SPACE
# you PRON
# can AUX
# wear VERB
# this DET
# one NUM
# around ADP
# the DET
# house NOUN
# . PUNCT
#
#  SPACE
# you PRON
# can AUX
# wear VERB
# this DET
# one NUM
# around ADP
# the DET
# house NOUN
# . PUNCT
# 	 SPACE
# next ADJ
# time NOUN
# i PRON
# 'll AUX
# soak VERB
# it PRON
# immediately ADV
# . PUNCT
#
#  SPACE
# my PRON
# fingers NOUN
# hurt VERB
# . PUNCT
# 	 SPACE
# why SCONJ
# do AUX
# they PRON
# hurt VERB
# ? PUNCT
#
#  SPACE
# why SCONJ
# do AUX
# they PRON
# hurt VERB
# ? PUNCT
# 	 SPACE
# i PRON
# type VERB
# too ADV
# much ADJ
# . PUNCT
#
#  SPACE
# i PRON
# type VERB
# too ADV
# much ADV
# . PUNCT
# 	 SPACE
# you PRON
# should AUX
# take VERB
# a DET
# break NOUN
# . PUNCT
#
#  SPACE
# you PRON
# should AUX
# take VERB
# a DET
# break NOUN
# . PUNCT
# 	 SPACE
# i PRON
# need VERB
# to PART
# type VERB
# to PART
# make VERB
# money NOUN
# . PUNCT
#
#  SPACE
# i PRON
# need VERB
# to PART
# type VERB
# to PART
# make VERB
# money NOUN
# . PUNCT
# 	 SPACE
# but CCONJ
# typing NOUN
# is AUX
# causing VERB
# you PRON
# pain NOUN
# . PUNCT
#
#  SPACE
# but CCONJ
# typing NOUN
# is AUX
# causing VERB
# you PRON
# pain NOUN
# . PUNCT
# 	 SPACE
# maybe ADV
# i PRON
# should AUX
# see VERB
# a DET
# doctor NOUN
# . PUNCT
#
#  SPACE
# maybe ADV
# i PRON
# should AUX
# see VERB
# a DET
# doctor NOUN
# . PUNCT
# 	 SPACE
# doctors NOUN
# are AUX
# too ADV
# expensive ADJ
# . PUNCT
#
#  SPACE
# doctors NOUN
# are AUX
# too ADV
# expensive ADJ
# . PUNCT
# 	 SPACE
# he PRON
# might AUX
# tell VERB
# me PRON
# to PART
# rest VERB
# for ADP
# a DET
# while NOUN
# . PUNCT
#
#  SPACE
# he PRON
# might AUX
# tell VERB
# me PRON
# to PART
# rest VERB
# for ADP
# a DET
# while NOUN
# . PUNCT
# 	 SPACE
# he PRON
# might AUX
# want VERB
# to PART
# cut VERB
# you PRON
# open ADJ
# . PUNCT
#
#  SPACE
# he PRON
# might AUX
# want VERB
# to PART
# cut VERB
# you PRON
# open ADJ
# . PUNCT
# 	 SPACE
# he PRON
# might AUX
# say VERB
# i PRON
# 'm AUX
# okay ADJ
# . PUNCT
#
#  SPACE
# he PRON
# might AUX
# say VERB
# i PRON
# 'm AUX
# okay ADJ
# . PUNCT
# 	 SPACE
# he PRON
# might AUX
# say VERB
# you PRON
# have VERB
# bone NOUN
# cancer NOUN
# . PUNCT
#
#  SPACE
# what PRON
# did AUX
# the DET
# doctor NOUN
# say VERB
# ? PUNCT
# 	 SPACE
# he PRON
# thinks VERB
# i PRON
# have VERB
# too ADV
# much ADJ
# stress NOUN
# . PUNCT
#
#  SPACE
# he PRON
# thinks VERB
# i PRON
# have VERB
# too ADV
# much ADJ
# stress NOUN
# . PUNCT
# 	 SPACE
# stress NOUN
# causes VERB
# your PRON
# stomachaches NOUN
# ? PUNCT
#
#  SPACE
# stress NOUN
# causes VERB
# your PRON
# stomachaches NOUN
# ? PUNCT
# 	 SPACE
# stress NOUN
# causes VERB
# different ADJ
# problems NOUN
# with ADP
# different ADJ
# people NOUN
# . PUNCT
#
#  SPACE
# stress NOUN
# causes VERB
# different ADJ
# problems NOUN
# with ADP
# different ADJ
# people NOUN
# . PUNCT
# 	 SPACE
# so ADV
# what PRON
# did AUX
# he PRON
# tell VERB
# you PRON
# to PART
# do VERB
# ? PUNCT
#
#  SPACE
# so ADV
# what PRON
# did AUX
# he PRON
# tell VERB
# you PRON
# to PART
# do VERB
# ? PUNCT
# 	 SPACE
# he PRON
# said VERB
# i PRON
# need VERB
# to PART
# think VERB
# positive ADJ
# . PUNCT
#
#  SPACE
# he PRON
# said VERB
# i PRON
# need VERB
# to PART
# think VERB
# positive ADJ
# . PUNCT
# 	 SPACE
# he PRON
# did AUX
# n't PART
# give VERB
# you PRON
# any DET
# medication NOUN
# ? PUNCT
#
#  SPACE
# he PRON
# did AUX
# n't PART
# give VERB
# you PRON
# any DET
# medication NOUN
# ? PUNCT
# 	 SPACE
# i PRON
# hate VERB
# medication NOUN
# . PUNCT
# it PRON
# makes VERB
# me PRON
# feel VERB
# different ADJ
# . PUNCT
#
#  SPACE
# i PRON
# hate VERB
# medication NOUN
# . PUNCT
# it PRON
# makes VERB
# me PRON
# feel VERB
# different ADJ
# . PUNCT
# 	 SPACE
# so ADV
# how SCONJ
# do AUX
# you PRON
# think VERB
# positive ADJ
# ? PUNCT
#
#  SPACE
# so ADV
# how SCONJ
# do AUX
# you PRON
# think VERB
# positive ADJ
# ? PUNCT
# 	 SPACE
# i PRON
# think VERB
# about ADP
# nice ADJ
# things NOUN
# . PUNCT
#
#  SPACE
# i PRON
# think VERB
# about ADP
# nice ADJ
# things NOUN
# . PUNCT
# 	 SPACE
# like ADP
# what PRON
# ? PUNCT
#
#  SPACE
# like ADP
# what PRON
# ? PUNCT
# 	 SPACE
# like INTJ
# a DET
# day NOUN
# at ADP
# the DET
# beach NOUN
# , PUNCT
# with ADP
# my PRON
# toes NOUN
# in ADP
# the DET
# sand NOUN
# . PUNCT
#
#  SPACE
# i PRON
# cut VERB
# my PRON
# finger NOUN
# . PUNCT
# 	 SPACE
# how SCONJ
# did AUX
# you PRON
# do VERB
# that PRON
# ? PUNCT
#
#  SPACE
# how SCONJ
# did AUX
# you PRON
# do VERB
# that PRON
# ? PUNCT
# 	 SPACE
# it PRON
# 's AUX
# a DET
# paper NOUN
# cut NOUN
# . PUNCT
#
#  SPACE
# it PRON
# 's AUX
# a DET
# paper NOUN
# cut NOUN
# . PUNCT
# 	 SPACE
# paper NOUN
# can AUX
# be AUX
# dangerous ADJ
# . PUNCT
#
#  SPACE
# paper NOUN
# can AUX
# be AUX
# dangerous ADJ
# . PUNCT
# 	 SPACE
# it PRON
# hurts VERB
# , PUNCT
# too ADV
# . PUNCT
#
#  SPACE
# it PRON
# hurts VERB
# , PUNCT
# too ADV
# . PUNCT
# 	 SPACE
# paper NOUN
# cuts NOUN
# can AUX
# hurt VERB
# a DET
# lot NOUN
# . PUNCT
#
#  SPACE
# paper NOUN
# cuts NOUN
# can AUX
# hurt VERB
# a DET
# lot NOUN
# . PUNCT
# 	 SPACE
# where SCONJ
# are AUX
# the DET
# band NOUN
# - PUNCT
# aids NOUN
# ? PUNCT
#
#  SPACE
# where SCONJ
# are AUX
# the DET
# band NOUN
# - PUNCT
# aids NOUN
# ? PUNCT
# 	 SPACE
# i PRON
# think VERB
# they PRON
# 're AUX
# in ADP
# the DET
# medicine NOUN
# cabinet NOUN
# . PUNCT
#
#  SPACE
# i PRON
# think VERB
# they PRON
# 're AUX
# in ADP
# the DET
# medicine NOUN
# cabinet NOUN
# . PUNCT
# 	 SPACE
# it PRON
# 's AUX
# on ADP
# the DET
# tip NOUN
# of ADP
# my PRON
# finger NOUN
# . PUNCT
#
#  SPACE
# it PRON
# 's AUX
# on ADP
# the DET
# tip NOUN
# of ADP
# my PRON
# finger NOUN
# . PUNCT
# 	 SPACE
# a DET
# band NOUN
# - PUNCT
# aid NOUN
# might AUX
# not PART
# work VERB
# . PUNCT
#
#  SPACE
# a DET
# band NOUN
# - PUNCT
# aid NOUN
# might AUX
# not PART
# work VERB
# . PUNCT
# 	 SPACE
# i PRON
# must AUX
# not PART
# use VERB
# this DET
# finger NOUN
# until SCONJ
# the DET
# cut NOUN
# heals VERB
# . PUNCT
#
#  SPACE
# i PRON
# must AUX
# not PART
# use VERB
# this DET
# finger NOUN
# until SCONJ
# the DET
# cut NOUN
# heals VERB
# . PUNCT
# 	 SPACE
# it PRON
# might AUX
# take VERB
# a DET
# day NOUN
# or CCONJ
# two NUM
# to PART
# heal VERB
# . PUNCT
#
#  SPACE
# do AUX
# you PRON
# smell VERB
# that PRON
# ? PUNCT
# 	 SPACE
# oh INTJ
# , PUNCT
# yes INTJ
# . PUNCT
#
#  SPACE
# oh INTJ
# , PUNCT
# yes INTJ
# . PUNCT
# 	 SPACE
# i PRON
# ca AUX
# n't PART
# stand VERB
# cigarette NOUN
# smoke NOUN
# . PUNCT
#
#  SPACE
# i PRON
# ca AUX
# n't PART
# stand VERB
# cigarette NOUN
# smoke NOUN
# . PUNCT
# 	 SPACE
# it PRON
# smells VERB
# so ADV
# bad ADJ
# . PUNCT
#
#  SPACE
# it PRON
# smells VERB
# so ADV
# bad ADJ
# . PUNCT
# 	 SPACE
# one NUM
# cigarette NOUN
# stinks VERB
# up ADP
# the DET
# whole ADJ
# sidewalk NOUN
# . PUNCT
#
#  SPACE
# one NUM
# cigarette NOUN
# stinks VERB
# up ADP
# the DET
# whole ADJ
# sidewalk NOUN
# . PUNCT
# 	 SPACE
# smokers NOUN
# think VERB
# they PRON
# are AUX
# so ADV
# cool ADJ
# . PUNCT
#
#  SPACE
# smokers NOUN
# think VERB
# they PRON
# are AUX
# so ADV
# cool ADJ
# . PUNCT
# 	 SPACE
# they PRON
# are AUX
# so ADV
# weak ADJ
# . PUNCT
#
#  SPACE
# they PRON
# are AUX
# so ADV
# weak ADJ
# . PUNCT
# 	 SPACE
# a DET
# little ADJ
# cigarette NOUN
# controls VERB
# them PRON
# . PUNCT
#
#  SPACE
# a DET
# little ADJ
# cigarette NOUN
# controls VERB
# them PRON
# . PUNCT
# 	 SPACE
# they PRON
# look VERB
# so ADV
# stupid ADJ
# taking VERB
# a DET
# puff NOUN
# . PUNCT
#
#  SPACE
# they PRON
# look VERB
# so ADV
# stupid ADJ
# taking VERB
# a DET
# puff NOUN
# . PUNCT
# 	 SPACE
# and CCONJ
# then ADV
# they PRON
# blow VERB
# smoke NOUN
# out ADP
# of ADP
# their PRON
# mouth NOUN
# . PUNCT
#
#  SPACE
# and CCONJ
# then ADV
# they PRON
# blow VERB
# smoke NOUN
# out ADP
# of ADP
# their PRON
# mouth NOUN
# . PUNCT
# 	 SPACE
# they PRON
# think VERB
# it PRON
# 's AUX
# cool ADJ
# . PUNCT
#
#  SPACE
# they PRON
# think VERB
# it PRON
# 's AUX
# cool ADJ
# . PUNCT
# 	 SPACE
# cigarettes NOUN
# stink VERB
# . PUNCT
#
#  SPACE
# do AUX
# you PRON
# have VERB
# a DET
# cold ADJ
# ? PUNCT
# 	 SPACE
# yes INTJ
# , PUNCT
# i PRON
# do VERB
# . PUNCT
#
#  SPACE
# yes INTJ
# , PUNCT
# i PRON
# do VERB
# . PUNCT
# 	 SPACE
# how SCONJ
# did AUX
# you PRON
# get VERB
# it PRON
# ? PUNCT
#
#  SPACE
# how SCONJ
# did AUX
# you PRON
# get VERB
# it PRON
# ? PUNCT
# 	 SPACE
# my PRON
# sister NOUN
# had VERB
# a DET
# cold NOUN
# . PUNCT
# she PRON
# gave VERB
# it PRON
# to ADP
# me PRON
# . PUNCT
#
#  SPACE
# my PRON
# sister NOUN
# had VERB
# a DET
# cold NOUN
# . PUNCT
# she PRON
# gave VERB
# it PRON
# to ADP
# me PRON
# . PUNCT
# 	 SPACE
# have AUX
# you PRON
# taken VERB
# anything PRON
# for ADP
# your PRON
# cold NOUN
# ? PUNCT
#
#  SPACE
# have AUX
# you PRON
# taken VERB
# anything PRON
# for ADP
# your PRON
# cold ADJ
# ? PUNCT
# 	 SPACE
# no INTJ
# , PUNCT
# i PRON
# just ADV
# blow VERB
# my PRON
# nose NOUN
# a DET
# lot NOUN
# . PUNCT
#
#  SPACE
# no INTJ
# , PUNCT
# i PRON
# just ADV
# blow VERB
# my PRON
# nose NOUN
# a DET
# lot NOUN
# . PUNCT
# 	 SPACE
# your PRON
# nose NOUN
# is AUX
# stopped VERB
# up ADP
# ? PUNCT
#
#  SPACE
# your PRON
# nose NOUN
# is AUX
# stopped VERB
# up ADP
# ? PUNCT
# 	 SPACE
# yes INTJ
# . PUNCT
# i PRON
# have VERB
# to PART
# breathe VERB
# through ADP
# my PRON
# mouth NOUN
# . PUNCT
#
#  SPACE
# yes INTJ
# . PUNCT
# i PRON
# have VERB
# to PART
# breathe VERB
# through ADP
# my PRON
# mouth NOUN
# . PUNCT
# 	 SPACE
# have AUX
# you PRON
# tried VERB
# nose NOUN
# drops NOUN
# ? PUNCT
#
#  SPACE
# have AUX
# you PRON
# tried VERB
# nose NOUN
# drops NOUN
# ? PUNCT
# 	 SPACE
# no INTJ
# , PUNCT
# i PRON
# do AUX
# n't PART
# like VERB
# nose NOUN
# drops NOUN
# . PUNCT
#
#  SPACE
# no INTJ
# , PUNCT
# i PRON
# do AUX
# n't PART
# like VERB
# nose NOUN
# drops NOUN
# . PUNCT
# 	 SPACE
# they PRON
# work VERB
# great ADJ
# . PUNCT
#
#  SPACE
# they PRON
# work VERB
# great ADJ
# . PUNCT
# 	 SPACE
# i PRON
# do AUX
# n't PART
# care VERB
# . PUNCT
# i PRON
# do AUX
# n't PART
# like VERB
# to PART
# put VERB
# drops NOUN
# in ADP
# my PRON
# nose NOUN
# . PUNCT
#
#  SPACE
# would AUX
# you PRON
# put VERB
# suntan ADJ
# lotion NOUN
# on ADP
# my PRON
# back NOUN
# , PUNCT
# please INTJ
# ? PUNCT
# 	 SPACE
# sure ADJ
# . PUNCT
#
#  SPACE
# sure ADJ
# . PUNCT
# 	 SPACE
# thank VERB
# you PRON
# . PUNCT
#
#  SPACE
# thank VERB
# you PRON
# . PUNCT
# 	 SPACE
# you PRON
# should AUX
# n't PART
# lie VERB
# in ADP
# the DET
# sun NOUN
# for ADP
# too ADV
# long ADV
# . PUNCT
#
#  SPACE
# you PRON
# should AUX
# n't PART
# lie VERB
# in ADP
# the DET
# sun NOUN
# for ADP
# too ADV
# long ADV
# . PUNCT
# 	 SPACE
# i PRON
# want VERB
# to PART
# get VERB
# a DET
# tan NOUN
# . PUNCT
# i PRON
# do AUX
# n't PART
# want VERB
# to PART
# look VERB
# so ADV
# pale ADJ
# . PUNCT
#
#  SPACE
# i PRON
# want VERB
# to PART
# get VERB
# a DET
# tan NOUN
# . PUNCT
# i PRON
# do AUX
# n't PART
# want VERB
# to PART
# look VERB
# so ADV
# pale ADJ
# . PUNCT
# 	 SPACE
# what PRON
# 's AUX
# wrong ADJ
# with ADP
# looking VERB
# pale NOUN
# ? PUNCT
#
#  SPACE
# what PRON
# 's AUX
# wrong ADJ
# with ADP
# looking VERB
# pale NOUN
# ? PUNCT
# 	 SPACE
# people NOUN
# think VERB
# you PRON
# might AUX
# be AUX
# sick ADJ
# . PUNCT
#
#  SPACE
# people NOUN
# think VERB
# you PRON
# might AUX
# be AUX
# sick ADJ
# . PUNCT
# 	 SPACE
# who PRON
# thinks VERB
# that PRON
# ? PUNCT
#
#  SPACE
# who PRON
# thinks VERB
# that PRON
# ? PUNCT
# 	 SPACE
# i PRON
# do AUX
# n't PART
# know VERB
# . PUNCT
#
#  SPACE
# i PRON
# do AUX
# n't PART
# know VERB
# . PUNCT
# 	 SPACE
# it PRON
# 's AUX
# better ADJ
# to PART
# be AUX
# pale ADJ
# than SCONJ
# to PART
# have VERB
# skin NOUN
# cancer NOUN
# . PUNCT
#
#  SPACE
# it PRON
# 's AUX
# better ADJ
# to PART
# be AUX
# pale ADJ
# than SCONJ
# to PART
# have VERB
# skin NOUN
# cancer NOUN
# . PUNCT
# 	 SPACE
# i PRON
# know VERB
# that PRON
# . PUNCT
#
#  SPACE
# i PRON
# know VERB
# that PRON
# . PUNCT
# 	 SPACE
# so ADV
# why SCONJ
# are AUX
# you PRON
# arguing VERB
# with ADP
# me PRON
# ? PUNCT
# do AUX
# n't PART
# lie VERB
# in ADP
# the DET
# sun NOUN
# too ADV
# long ADV
# ! PUNCT
#
#  SPACE
# i PRON
# ca AUX
# n't PART
# quit VERB
# smoking NOUN
# . PUNCT
# 	 SPACE
# of ADV
# course NOUN
# you PRON
# can AUX
# . PUNCT
#
#  SPACE
# of ADV
# course NOUN
# you PRON
# can AUX
# . PUNCT
# 	 SPACE
# i PRON
# do AUX
# n't PART
# have VERB
# enough ADJ
# will AUX
# power VERB
# . PUNCT
#
#  SPACE
# i PRON
# do AUX
# n't PART
# have VERB
# enough ADJ
# will AUX
# power VERB
# . PUNCT
# 	 SPACE
# of ADV
# course NOUN
# you PRON
# do VERB
# . PUNCT
#
#  SPACE
# of ADV
# course NOUN
# you PRON
# do VERB
# . PUNCT
# 	 SPACE
# i PRON
# wish VERB
# i PRON
# had AUX
# never ADV
# started VERB
# . PUNCT
#
#  SPACE
# i PRON
# wish VERB
# i PRON
# had AUX
# never ADV
# started VERB
# . PUNCT
# 	 SPACE
# so ADV
# does VERB
# every DET
# smoker NOUN
# . PUNCT
#
#  SPACE
# so ADV
# does VERB
# every DET
# smoker NOUN
# . PUNCT
# 	 SPACE
# i PRON
# 've AUX
# tried VERB
# to PART
# quit VERB
# so ADV
# many ADJ
# times NOUN
# . PUNCT
#
#  SPACE
# i PRON
# 've AUX
# tried VERB
# to PART
# quit VERB
# so ADV
# many ADJ
# times NOUN
# . PUNCT
# 	 SPACE
# so ADV
# has VERB
# everyone PRON
# else ADV
# . PUNCT
#
#  SPACE
# so ADV
# has VERB
# everyone PRON
# else ADV
# . PUNCT
# 	 SPACE
# nothing PRON
# seems VERB
# to PART
# work VERB
# . PUNCT
#
#  SPACE
# nothing PRON
# seems VERB
# to PART
# work VERB
# . PUNCT
# 	 SPACE
# all PRON
# it PRON
# takes VERB
# is AUX
# will AUX
# power NOUN
# , PUNCT
# and CCONJ
# you PRON
# have VERB
# it PRON
# . PUNCT
#
#  SPACE
# all PRON
# it PRON
# takes VERB
# is AUX
# will AUX
# power NOUN
# , PUNCT
# and CCONJ
# you PRON
# have VERB
# it PRON
# . PUNCT
# 	 SPACE
# then ADV
# why SCONJ
# ca AUX
# n't PART
# i PRON
# quit VERB
# ? PUNCT
#
#  SPACE
# then ADV
# why SCONJ
# ca AUX
# n't PART
# i PRON
# quit VERB
# ? PUNCT
# 	 SPACE
# you PRON
# have VERB
# to PART
# believe VERB
# in ADP
# yourself PRON
# . PUNCT
#
#  SPACE
# my PRON
# back NOUN
# is AUX
# killing VERB
# me PRON
# . PUNCT
# 	 SPACE
# what PRON
# did AUX
# you PRON
# do VERB
# ? PUNCT
#
#  SPACE
# what PRON
# did AUX
# you PRON
# do VERB
# ? PUNCT
# 	 SPACE
# i PRON
# got VERB
# out ADP
# of ADP
# my PRON
# car NOUN
# . PUNCT
#
#  SPACE
# i PRON
# got VERB
# out ADP
# of ADP
# my PRON
# car NOUN
# . PUNCT
# 	 SPACE
# that PRON
# 's AUX
# it PRON
# ? PUNCT
#
#  SPACE
# that PRON
# 's AUX
# it PRON
# ? PUNCT
# 	 SPACE
# i PRON
# injured VERB
# my PRON
# back NOUN
# one NUM
# time NOUN
# just ADV
# by ADP
# sneezing VERB
# . PUNCT
#
#  SPACE
# i PRON
# injured VERB
# my PRON
# back NOUN
# one NUM
# time NOUN
# just ADV
# by ADP
# sneezing VERB
# . PUNCT
# 	 SPACE
# you PRON
# should AUX
# see VERB
# a DET
# doctor NOUN
# . PUNCT
#
#  SPACE
# you PRON
# should AUX
# see VERB
# a DET
# doctor NOUN
# . PUNCT
# 	 SPACE
# my PRON
# doctor NOUN
# said VERB
# i PRON
# need VERB
# surgery NOUN
# . PUNCT
#
#  SPACE
# my PRON
# doctor NOUN
# said VERB
# i PRON
# need VERB
# surgery NOUN
# . PUNCT
# 	 SPACE
# so ADV
# ? PUNCT
#
#  SPACE
# so ADV
# ? PUNCT
# 	 SPACE
# so ADV
# , PUNCT
# forget VERB
# it PRON
# . PUNCT
#
#  SPACE
# so ADV
# , PUNCT
# forget VERB
# it PRON
# . PUNCT
# 	 SPACE
# you PRON
# do AUX
# n't PART
# have VERB
# the DET
# money NOUN
# ? PUNCT
#
#  SPACE
# you PRON
# do AUX
# n't PART
# have VERB
# the DET
# money NOUN
# ? PUNCT
# 	 SPACE
# i PRON
# have VERB
# no DET
# insurance NOUN
# . PUNCT
#
#  SPACE
# i PRON
# have VERB
# no DET
# insurance NOUN
# . PUNCT
# 	 SPACE
# maybe ADV
# a DET
# back ADJ
# rub NOUN
# would AUX
# help VERB
# . PUNCT
#
#  SPACE
# my PRON
# brother NOUN
# smokes VERB
# three NUM
# packs NOUN
# a DET
# day NOUN
# . PUNCT
# 	 SPACE
# three NUM
# packs NOUN
# of ADP
# what PRON
# ? PUNCT
#
#  SPACE
# three NUM
# packs NOUN
# of ADP
# what PRON
# ? PUNCT
# 	 SPACE
# cigarettes NOUN
# , PUNCT
# of ADP
# course NOUN
# . PUNCT
#
#  SPACE
# cigarettes NOUN
# , PUNCT
# of ADP
# course NOUN
# . PUNCT
# 	 SPACE
# how SCONJ
# can AUX
# he PRON
# do VERB
# that PRON
# ? PUNCT
#
#  SPACE
# how SCONJ
# can AUX
# he PRON
# do VERB
# that PRON
# ? PUNCT
# 	 SPACE
# when SCONJ
# he PRON
# is AUX
# almost ADV
# finished VERB
# with ADP
# one NUM
# cigarette NOUN
# , PUNCT
# he PRON
# uses VERB
# it PRON
# to PART
# light VERB
# another PRON
# . PUNCT
#
#  SPACE
# when SCONJ
# he PRON
# is AUX
# almost ADV
# finished VERB
# with ADP
# one NUM
# cigarette NOUN
# , PUNCT
# he PRON
# uses VERB
# it PRON
# to PART
# light VERB
# another PRON
# . PUNCT
# 	 SPACE
# he PRON
# 's AUX
# a DET
# chain NOUN
# smoker NOUN
# . PUNCT
#
#  SPACE
# he PRON
# 's AUX
# a DET
# chain NOUN
# smoker NOUN
# . PUNCT
# 	 SPACE
# he PRON
# 's AUX
# been AUX
# a DET
# chain NOUN
# smoker NOUN
# for ADP
# 30 NUM
# years NOUN
# . PUNCT
#
#  SPACE
# he PRON
# 's AUX
# been AUX
# a DET
# chain NOUN
# smoker NOUN
# for ADP
# 30 NUM
# years NOUN
# . PUNCT
# 	 SPACE
# that PRON
# 's AUX
# unbelievable ADJ
# . PUNCT
# can AUX
# he PRON
# still ADV
# breathe VERB
# ? PUNCT
#
#  SPACE
# that PRON
# 's AUX
# unbelievable ADJ
# . PUNCT
# can AUX
# he PRON
# still ADV
# breathe VERB
# ? PUNCT
# 	 SPACE
# he PRON
# can AUX
# , PUNCT
# but CCONJ
# the DET
# people NOUN
# around ADP
# him PRON
# ca AUX
# n't PART
# . PUNCT
#
#  SPACE
# he PRON
# can AUX
# , PUNCT
# but CCONJ
# the DET
# people NOUN
# around ADP
# him PRON
# ca AUX
# n't PART
# . PUNCT
# 	 SPACE
# how SCONJ
# can AUX
# he PRON
# still ADV
# be AUX
# alive ADJ
# ? PUNCT
#
#  SPACE
# how SCONJ
# can AUX
# he PRON
# still ADV
# be AUX
# alive ADJ
# ? PUNCT
# 	 SPACE
# his PRON
# doctor NOUN
# says VERB
# his PRON
# heart NOUN
# and CCONJ
# lungs NOUN
# are AUX
# strong ADJ
# and CCONJ
# healthy ADJ
# . PUNCT
#
#  SPACE
# his PRON
# doctor NOUN
# says VERB
# his PRON
# heart NOUN
# and CCONJ
# lungs NOUN
# are AUX
# strong ADJ
# and CCONJ
# healthy ADJ
# . PUNCT
# 	 SPACE
# maybe ADV
# i PRON
# should AUX
# start VERB
# smoking NOUN
# . PUNCT
#
#  SPACE
# i PRON
# hate VERB
# brushing VERB
# my PRON
# teeth NOUN
# . PUNCT
# 	 SPACE
# it PRON
# 's AUX
# such DET
# a DET
# chore NOUN
# . PUNCT
#
#  SPACE
# it PRON
# 's AUX
# such DET
# a DET
# chore NOUN
# . PUNCT
# 	 SPACE
# brush NOUN
# , PUNCT
# brush NOUN
# . PUNCT
# spit PROPN
# , PUNCT
# spit NOUN
# . PUNCT
#
#  SPACE
# brush NOUN
# , PUNCT
# brush NOUN
# . PUNCT
# spit PROPN
# , PUNCT
# spit PROPN
# . PUNCT
# 	 SPACE
# what PRON
# did AUX
# they PRON
# do VERB
# in ADP
# the DET
# old ADJ
# days NOUN
# ? PUNCT
#
#  SPACE
# what PRON
# did AUX
# they PRON
# do VERB
# in ADP
# the DET
# old ADJ
# days NOUN
# ? PUNCT
# 	 SPACE
# they PRON
# brushed VERB
# with ADP
# their PRON
# fingers NOUN
# . PUNCT
#
#  SPACE
# they PRON
# brushed VERB
# with ADP
# their PRON
# fingers NOUN
# . PUNCT
# 	 SPACE
# they PRON
# also ADV
# ate VERB
# with ADP
# their PRON
# fingers NOUN
# ! PUNCT
#
#  SPACE
# they PRON
# also ADV
# ate VERB
# with ADP
# their PRON
# fingers NOUN
# ! PUNCT
# 	 SPACE
# why SCONJ
# do AUX
# they PRON
# call VERB
# it PRON
# the DET
# good ADJ
# old ADJ
# days NOUN
# ? PUNCT
#
#  SPACE
# why SCONJ
# do AUX
# they PRON
# call VERB
# it PRON
# the DET
# good ADJ
# old ADJ
# days NOUN
# ? PUNCT
# 	 SPACE
# maybe ADV
# because SCONJ
# they PRON
# did AUX
# n't PART
# have VERB
# to PART
# brush VERB
# and CCONJ
# floss NOUN
# . PUNCT
#
#  SPACE
# maybe ADV
# because SCONJ
# they PRON
# did AUX
# n't PART
# have VERB
# to PART
# brush VERB
# and CCONJ
# floss NOUN
# . PUNCT
# 	 SPACE
# who PRON
# invented VERB
# flossing VERB
# ? PUNCT
#
#  SPACE
# who PRON
# invented VERB
# flossing VERB
# ? PUNCT
# 	 SPACE
# a DET
# dentist NOUN
# , PUNCT
# i PRON
# 'm AUX
# sure ADJ
# . PUNCT
#
#  SPACE
# a DET
# dentist NOUN
# , PUNCT
# i PRON
# 'm AUX
# sure ADJ
# . PUNCT
# 	 SPACE
# i PRON
# hate VERB
# flossing VERB
# more ADV
# than ADP
# brushing VERB
# ! PUNCT
#
#  SPACE
# i PRON
# hate VERB
# flossing VERB
# more ADV
# than ADP
# brushing VERB
# ! PUNCT
# 	 SPACE
# i PRON
# ca AUX
# n't PART
# wait VERB
# till SCONJ
# all DET
# my PRON
# teeth NOUN
# fall VERB
# out ADP
# . PUNCT
#
#  SPACE
# let VERB
# 's PRON
# stop VERB
# for ADP
# a DET
# while NOUN
# . PUNCT
# i PRON
# need VERB
# a DET
# break NOUN
# and CCONJ
# some DET
# water NOUN
# . PUNCT
# 	 SPACE
# this DET
# trail NOUN
# is AUX
# hard ADJ
# to PART
# climb VERB
# . PUNCT
#
#  SPACE
# this DET
# trail NOUN
# is AUX
# hard ADJ
# to PART
# climb VERB
# . PUNCT
# 	 SPACE
# especially ADV
# on ADP
# a DET
# hot ADJ
# day NOUN
# like ADP
# this PRON
# . PUNCT
#
#  SPACE
# especially ADV
# on ADP
# a DET
# hot ADJ
# day NOUN
# like ADP
# this PRON
# . PUNCT
# 	 SPACE
# i PRON
# ca AUX
# n't PART
# believe VERB
# we PRON
# have AUX
# n't PART
# seen VERB
# any DET
# animals NOUN
# . PUNCT
#
#  SPACE
# i PRON
# ca AUX
# n't PART
# believe VERB
# we PRON
# have AUX
# n't PART
# seen VERB
# any DET
# animals NOUN
# . PUNCT
# 	 SPACE
# thank VERB
# goodness NOUN
# ! PUNCT
# i PRON
# do AUX
# n't PART
# want VERB
# to PART
# see VERB
# any DET
# wild ADJ
# animals NOUN
# . PUNCT
#
#  SPACE
# thank VERB
# goodness NOUN
# ! PUNCT
# i PRON
# do AUX
# n't PART
# want VERB
# to PART
# see VERB
# any DET
# wild ADJ
# animals NOUN
# . PUNCT
# 	 SPACE
# all PRON
# we PRON
# 've AUX
# seen VERB
# so ADV
# far ADV
# is AUX
# a DET
# couple NOUN
# of ADP
# lizards NOUN
# . PUNCT
#
#  SPACE
# all PRON
# we PRON
# 've AUX
# seen VERB
# so ADV
# far ADV
# is AUX
# a DET
# couple NOUN
# of ADP
# lizards NOUN
# . PUNCT
# 	 SPACE
# we PRON
# 're AUX
# hiking VERB
# to PART
# lose VERB
# weight NOUN
# , PUNCT
# not PART
# to PART
# see VERB
# goats NOUN
# and CCONJ
# bears NOUN
# . PUNCT
#
#  SPACE
# we PRON
# 're AUX
# hiking VERB
# to PART
# lose VERB
# weight NOUN
# , PUNCT
# not PART
# to PART
# see VERB
# goats NOUN
# and CCONJ
# bears NOUN
# . PUNCT
# 	 SPACE
# i PRON
# bet VERB
# i PRON
# 've AUX
# lost VERB
# a DET
# couple NOUN
# of ADP
# pounds NOUN
# already ADV
# . PUNCT
#
#  SPACE
# i PRON
# bet VERB
# i PRON
# 've AUX
# lost VERB
# a DET
# couple NOUN
# of ADP
# pounds NOUN
# already ADV
# . PUNCT
# 	 SPACE
# all PRON
# you PRON
# 've AUX
# lost VERB
# is AUX
# some DET
# sweat NOUN
# . PUNCT
#
#  SPACE
# all PRON
# you PRON
# 've AUX
# lost VERB
# is AUX
# some DET
# sweat NOUN
# . PUNCT
# 	 SPACE
# i PRON
# have AUX
# n't PART
# even ADV
# lost VERB
# one NUM
# pound NOUN
# of ADP
# fat NOUN
# ? PUNCT
#
#  SPACE
# i PRON
# have AUX
# n't PART
# even ADV
# lost VERB
# one NUM
# pound NOUN
# of ADP
# fat NOUN
# ? PUNCT
# 	 SPACE
# if SCONJ
# you PRON
# want VERB
# to PART
# lose VERB
# fat NOUN
# , PUNCT
# you PRON
# 've AUX
# got VERB
# to PART
# do VERB
# this DET
# hike NOUN
# every DET
# day NOUN
# . PUNCT
#
#  SPACE
# if SCONJ
# you PRON
# want VERB
# to PART
# lose VERB
# fat NOUN
# , PUNCT
# you PRON
# 've AUX
# got VERB
# to PART
# do VERB
# this DET
# hike NOUN
# every DET
# day NOUN
# . PUNCT
# 	 SPACE
# okay INTJ
# , PUNCT
# but CCONJ
# let VERB
# 's PRON
# hike VERB
# in ADP
# town NOUN
# . PUNCT
# at ADP
# least ADJ
# there PRON
# are VERB
# cats NOUN
# and CCONJ
# dogs NOUN
# to PART
# see VERB
# . PUNCT
#
#  SPACE
# oh INTJ
# no INTJ
# , PUNCT
# another DET
# pimple NOUN
# on ADP
# my PRON
# face NOUN
# . PUNCT
# 	 SPACE
# pimples NOUN
# suck VERB
# . PUNCT
#
#  SPACE
# pimples NOUN
# suck VERB
# . PUNCT
# 	 SPACE
# it PRON
# seems VERB
# like SCONJ
# i PRON
# get VERB
# a DET
# new ADJ
# pimple NOUN
# almost ADV
# every PRON
# day NOUN
# . PUNCT
#
#  SPACE
# it PRON
# seems VERB
# like SCONJ
# i PRON
# get VERB
# a DET
# new ADJ
# pimple NOUN
# almost ADV
# every PRON
# day NOUN
# . PUNCT
# 	 SPACE
# maybe ADV
# it PRON
# 's AUX
# something PRON
# in ADP
# your PRON
# diet NOUN
# . PUNCT
#
#  SPACE
# maybe ADV
# it PRON
# 's AUX
# something PRON
# in ADP
# your PRON
# diet NOUN
# . PUNCT
# 	 SPACE
# no INTJ
# , PUNCT
# i PRON
# eat VERB
# the DET
# same ADJ
# things NOUN
# day NOUN
# after ADP
# day NOUN
# . PUNCT
#
#  SPACE
# no INTJ
# , PUNCT
# i PRON
# eat VERB
# the DET
# same ADJ
# things NOUN
# day NOUN
# after ADP
# day NOUN
# . PUNCT
# 	 SPACE
# then ADV
# maybe ADV
# it PRON
# 's AUX
# in ADP
# your PRON
# genes NOUN
# . PUNCT
#
#  SPACE
# then ADV
# maybe ADV
# it PRON
# 's AUX
# in ADP
# your PRON
# genes NOUN
# . PUNCT
# 	 SPACE
# you PRON
# might AUX
# be AUX
# right ADJ
# . PUNCT
#
#  SPACE
# you PRON
# might AUX
# be AUX
# right ADJ
# . PUNCT
# 	 SPACE
# do AUX
# pimples NOUN
# run VERB
# in ADP
# your PRON
# family NOUN
# ? PUNCT
#
#  SPACE
# do AUX
# pimples NOUN
# run VERB
# in ADP
# your PRON
# family NOUN
# ? PUNCT
# 	 SPACE
# not PART
# that SCONJ
# i PRON
# 've AUX
# noticed VERB
# . PUNCT
#
#  SPACE
# not PART
# that SCONJ
# i PRON
# 've AUX
# noticed VERB
# . PUNCT
# 	 SPACE
# well INTJ
# , PUNCT
# maybe ADV
# it PRON
# 's AUX
# from ADP
# the DET
# pollution NOUN
# in ADP
# the DET
# air NOUN
# . PUNCT
#
#  SPACE
# well INTJ
# , PUNCT
# maybe ADV
# it PRON
# 's AUX
# from ADP
# the DET
# pollution NOUN
# in ADP
# the DET
# air NOUN
# . PUNCT
# 	 SPACE
# whatever PRON
# the DET
# cause NOUN
# , PUNCT
# i PRON
# hate AUX
# seeing VERB
# them PRON
# on ADP
# my PRON
# face NOUN
# . PUNCT
#
#  SPACE
# whatever PRON
# the DET
# cause NOUN
# , PUNCT
# i PRON
# hate AUX
# seeing VERB
# them PRON
# on ADP
# my PRON
# face NOUN
# . PUNCT
# 	 SPACE
# well ADV
# , PUNCT
# on ADP
# the DET
# bright ADJ
# side NOUN
# , PUNCT
# they PRON
# 're AUX
# fun ADJ
# to PART
# pop VERB
# . PUNCT
#
#  SPACE
# do AUX
# you PRON
# believe VERB
# everything PRON
# you PRON
# hear VERB
# ? PUNCT
# 	 SPACE
# i PRON
# do AUX
# n't PART
# believe VERB
# anything PRON
# i PRON
# do AUX
# n't PART
# see VERB
# with ADP
# my PRON
# own ADJ
# eyes NOUN
# . PUNCT
#
#  SPACE
# i PRON
# do AUX
# n't PART
# believe VERB
# anything PRON
# i PRON
# do AUX
# n't PART
# see VERB
# with ADP
# my PRON
# own ADJ
# eyes NOUN
# . PUNCT
# 	 SPACE
# you PRON
# ca AUX
# n't PART
# believe VERB
# what PRON
# you PRON
# hear VERB
# on ADP
# tv NOUN
# or CCONJ
# radio NOUN
# . PUNCT
#
#  SPACE
# you PRON
# ca AUX
# n't PART
# believe VERB
# what PRON
# you PRON
# hear VERB
# on ADP
# tv NOUN
# or CCONJ
# radio NOUN
# . PUNCT
# 	 SPACE
# you PRON
# ca AUX
# n't PART
# believe VERB
# what PRON
# you PRON
# read VERB
# in ADP
# the DET
# newspapers NOUN
# . PUNCT
#
#  SPACE
# you PRON
# ca AUX
# n't PART
# believe VERB
# what PRON
# you PRON
# read VERB
# in ADP
# the DET
# newspapers NOUN
# . PUNCT
# 	 SPACE
# everyone PRON
# tells VERB
# you PRON
# a DET
# different ADJ
# story NOUN
# about ADP
# the DET
# same ADJ
# thing NOUN
# . PUNCT
#
#  SPACE
# everyone PRON
# tells VERB
# you PRON
# a DET
# different ADJ
# story NOUN
# about ADP
# the DET
# same ADJ
# thing NOUN
# . PUNCT
# 	 SPACE
# three NUM
# different ADJ
# people NOUN
# will AUX
# give VERB
# you PRON
# three NUM
# different ADJ
# stories NOUN
# . PUNCT
#
#  SPACE
# three NUM
# different ADJ
# people NOUN
# will AUX
# give VERB
# you PRON
# three NUM
# different ADJ
# stories NOUN
# . PUNCT
# 	 SPACE
# and CCONJ
# the DET
# government NOUN
# will AUX
# give VERB
# you PRON
# a DET
# fourth ADJ
# story NOUN
# . PUNCT
#
#  SPACE
# and CCONJ
# the DET
# government NOUN
# will AUX
# give VERB
# you PRON
# a DET
# fourth ADJ
# story NOUN
# . PUNCT
# 	 SPACE
# yes INTJ
# , PUNCT
# like SCONJ
# the DET
# government NOUN
# says VERB
# not PART
# to PART
# worry VERB
# about ADP
# the DET
# swine PROPN
# flu NOUN
# . PUNCT
#
#  SPACE
# yes INTJ
# , PUNCT
# like ADP
# the DET
# government NOUN
# says VERB
# not PART
# to PART
# worry VERB
# about ADP
# the DET
# swine PROPN
# flu NOUN
# . PUNCT
# 	 SPACE
# but CCONJ
# the DET
# swine PROPN
# flu PROPN
# just ADV
# killed VERB
# 20 NUM
# people NOUN
# in ADP
# mexico PROPN
# . PUNCT
#
#  SPACE
# but CCONJ
# the DET
# swine PROPN
# flu PROPN
# just ADV
# killed VERB
# 20 NUM
# people NOUN
# in ADP
# mexico PROPN
# . PUNCT
# 	 SPACE
# the DET
# government NOUN
# says VERB
# we PRON
# have VERB
# nothing PRON
# to PART
# worry VERB
# about ADP
# . PUNCT
#
#  SPACE
# the DET
# government NOUN
# says VERB
# we PRON
# have VERB
# nothing PRON
# to PART
# worry VERB
# about ADP
# . PUNCT
# 	 SPACE
# then ADV
# why SCONJ
# are AUX
# some DET
# schools NOUN
# telling VERB
# the DET
# kids NOUN
# to PART
# stay VERB
# home ADV
# ? PUNCT
#
#  SPACE
# then ADV
# why SCONJ
# are AUX
# some DET
# schools NOUN
# telling VERB
# the DET
# kids NOUN
# to PART
# stay VERB
# home ADV
# ? PUNCT
# 	 SPACE
# the DET
# government NOUN
# says VERB
# to PART
# wash VERB
# our PRON
# hands NOUN
# frequently ADV
# , PUNCT
# and CCONJ
# we PRON
# 'll AUX
# all ADV
# be AUX
# okay ADJ
# . PUNCT
#
#  SPACE
# do AUX
# n't PART
# pick VERB
# your PRON
# nose NOUN
# . PUNCT
# 	 SPACE
# i PRON
# was AUX
# n't PART
# picking VERB
# my PRON
# nose NOUN
# . PUNCT
#
#  SPACE
# i PRON
# was AUX
# n't PART
# picking VERB
# my PRON
# nose NOUN
# . PUNCT
# 	 SPACE
# what PRON
# were AUX
# you PRON
# doing VERB
# ? PUNCT
#
#  SPACE
# what PRON
# were AUX
# you PRON
# doing VERB
# ? PUNCT
# 	 SPACE
# i PRON
# was AUX
# scratching VERB
# my PRON
# nose NOUN
# . PUNCT
#
#  SPACE
# i PRON
# was AUX
# scratching VERB
# my PRON
# nose NOUN
# . PUNCT
# 	 SPACE
# i PRON
# think VERB
# i PRON
# know VERB
# the DET
# difference NOUN
# between ADP
# picking VERB
# and CCONJ
# scratching VERB
# . PUNCT
#
#  SPACE
# i PRON
# think VERB
# i PRON
# know VERB
# the DET
# difference NOUN
# between ADP
# picking VERB
# and CCONJ
# scratching VERB
# . PUNCT
# 	 SPACE
# okay INTJ
# , PUNCT
# mom NOUN
# , PUNCT
# maybe ADV
# i PRON
# was AUX
# picking VERB
# it PRON
# a DET
# little ADJ
# bit NOUN
# . PUNCT
#
#  SPACE
# okay INTJ
# , PUNCT
# mom NOUN
# , PUNCT
# maybe ADV
# i PRON
# was AUX
# picking VERB
# it PRON
# a DET
# little ADJ
# bit NOUN
# . PUNCT
# 	 SPACE
# use VERB
# a DET
# tissue NOUN
# next ADJ
# time NOUN
# . PUNCT
#
#  SPACE
# use VERB
# a DET
# tissue NOUN
# next ADJ
# time NOUN
# . PUNCT
# 	 SPACE
# i PRON
# did AUX
# n't PART
# have VERB
# a DET
# tissue NOUN
# . PUNCT
#
#  SPACE
# i PRON
# did AUX
# n't PART
# have VERB
# a DET
# tissue NOUN
# . PUNCT
# 	 SPACE
# then ADV
# wait VERB
# till SCONJ
# you PRON
# find VERB
# a DET
# tissue NOUN
# . PUNCT
#
#  SPACE
# then ADV
# wait VERB
# till SCONJ
# you PRON
# find VERB
# a DET
# tissue NOUN
# . PUNCT
# 	 SPACE
# i PRON
# could AUX
# n't PART
# wait VERB
# . PUNCT
# it PRON
# was AUX
# an DET
# emergency NOUN
# . PUNCT
#
#  SPACE
# i PRON
# could AUX
# n't PART
# wait VERB
# . PUNCT
# it PRON
# was AUX
# an DET
# emergency NOUN
# . PUNCT
# 	 SPACE
# oh INTJ
# , PUNCT
# really ADV
# ? PUNCT
# maybe ADV
# you PRON
# should AUX
# have AUX
# called VERB
# 911 NUM
# . PUNCT
#
#  SPACE
# oh INTJ
# , PUNCT
# really ADV
# ? PUNCT
# maybe ADV
# you PRON
# should AUX
# have AUX
# called VERB
# 911 NUM
# . PUNCT
# 	 SPACE
# it PRON
# was AUX
# n't PART
# that DET
# kind NOUN
# of ADP
# emergency NOUN
# . PUNCT
#
#  SPACE
# our PRON
# tv NOUN
# remote NOUN
# is AUX
# filthy ADJ
# . PUNCT
# 	 SPACE
# yes INTJ
# , PUNCT
# it PRON
# 's AUX
# covered VERB
# with ADP
# crud PROPN
# . PUNCT
#
#  SPACE
# yes INTJ
# , PUNCT
# it PRON
# 's AUX
# covered VERB
# with ADP
# crud PROPN
# . PUNCT
# 	 SPACE
# i PRON
# 'm AUX
# going VERB
# to PART
# clean VERB
# it PRON
# . PUNCT
#
#  SPACE
# i PRON
# 'm AUX
# going VERB
# to PART
# clean VERB
# it PRON
# . PUNCT
# 	 SPACE
# do AUX
# n't PART
# use VERB
# water NOUN
# on ADP
# it PRON
# ! PUNCT
#
#  SPACE
# do AUX
# n't PART
# use VERB
# water NOUN
# on ADP
# it PRON
# ! PUNCT
# 	 SPACE
# i PRON
# 'll AUX
# use VERB
# a DET
# damp ADJ
# cloth NOUN
# . PUNCT
#
#  SPACE
# i PRON
# 'll AUX
# use VERB
# a DET
# damp ADJ
# cloth NOUN
# . PUNCT
# 	 SPACE
# do AUX
# n't PART
# let VERB
# water NOUN
# get VERB
# into ADP
# any PRON
# of ADP
# the DET
# cracks NOUN
# . PUNCT
#
#  SPACE
# do AUX
# n't PART
# let VERB
# water NOUN
# get VERB
# into ADP
# any PRON
# of ADP
# the DET
# cracks NOUN
# . PUNCT
# 	 SPACE
# i PRON
# 'll AUX
# squeeze VERB
# the DET
# cloth NOUN
# so SCONJ
# it PRON
# 's AUX
# almost ADV
# dry ADJ
# . PUNCT
#
#  SPACE
# i PRON
# 'll AUX
# squeeze VERB
# the DET
# cloth NOUN
# so SCONJ
# it PRON
# 's AUX
# almost ADV
# dry ADJ
# . PUNCT
# 	 SPACE
# do AUX
# n't PART
# rub VERB
# the DET
# numbers NOUN
# off ADP
# the DET
# remote NOUN
# . PUNCT
#
#  SPACE
# do AUX
# n't PART
# rub VERB
# the DET
# numbers NOUN
# off ADP
# the DET
# remote NOUN
# . PUNCT
# 	 SPACE
# i PRON
# will AUX
# rub VERB
# gently ADV
# but CCONJ
# firmly ADV
# . PUNCT
#
#  SPACE
# i PRON
# will AUX
# rub VERB
# gently ADV
# but CCONJ
# firmly ADV
# . PUNCT
# 	 SPACE
# do VERB
# it PRON
# quickly ADV
# , PUNCT
# please INTJ
# , PUNCT
# so SCONJ
# i PRON
# can AUX
# change VERB
# channels NOUN
# during ADP
# commercials NOUN
# . PUNCT
#
#  SPACE
# do VERB
# it PRON
# quickly ADV
# , PUNCT
# please INTJ
# , PUNCT
# so SCONJ
# i PRON
# can AUX
# change VERB
# channels NOUN
# during ADP
# commercials NOUN
# . PUNCT
# 	 SPACE
# i PRON
# 'll AUX
# give VERB
# it PRON
# back ADV
# to ADP
# you PRON
# in ADP
# a DET
# couple NOUN
# of ADP
# minutes NOUN
# . PUNCT
#
#  SPACE
# i PRON
# 'll AUX
# give VERB
# it PRON
# back ADV
# to ADP
# you PRON
# in ADP
# a DET
# couple NOUN
# of ADP
# minutes NOUN
# . PUNCT
# 	 SPACE
# maybe ADV
# we PRON
# should AUX
# put VERB
# it PRON
# in ADP
# a DET
# plastic ADJ
# bag NOUN
# to PART
# keep VERB
# it PRON
# clean ADJ
# . PUNCT
#
#  SPACE
# my PRON
# ear NOUN
# is AUX
# killing VERB
# me PRON
# . PUNCT
# 	 SPACE
# what PRON
# 's AUX
# the DET
# matter NOUN
# ? PUNCT
#
#  SPACE
# what PRON
# 's AUX
# the DET
# matter NOUN
# ? PUNCT
# 	 SPACE
# i PRON
# was AUX
# on ADP
# a DET
# plane NOUN
# . PUNCT
#
#  SPACE
# i PRON
# was AUX
# on ADP
# a DET
# plane NOUN
# . PUNCT
# 	 SPACE
# so ADV
# ? PUNCT
#
#  SPACE
# so ADV
# ? PUNCT
# 	 SPACE
# so ADV
# , PUNCT
# every DET
# time NOUN
# the DET
# plane NOUN
# goes VERB
# up ADV
# , PUNCT
# my PRON
# ear NOUN
# starts VERB
# to PART
# hurt VERB
# . PUNCT
#
#  SPACE
# so ADV
# , PUNCT
# every DET
# time NOUN
# the DET
# plane NOUN
# goes VERB
# up ADV
# , PUNCT
# my PRON
# ear NOUN
# starts VERB
# to PART
# hurt VERB
# . PUNCT
# 	 SPACE
# that PRON
# 's AUX
# no DET
# good ADJ
# . PUNCT
#
#  SPACE
# that PRON
# 's AUX
# no DET
# good ADJ
# . PUNCT
# 	 SPACE
# sometimes ADV
# the DET
# pain NOUN
# goes VERB
# away ADV
# , PUNCT
# and CCONJ
# sometimes ADV
# it PRON
# does VERB
# n't PART
# . PUNCT
#
#  SPACE
# sometimes ADV
# the DET
# pain NOUN
# goes VERB
# away ADV
# , PUNCT
# and CCONJ
# sometimes ADV
# it PRON
# does VERB
# n't PART
# . PUNCT
# 	 SPACE
# have AUX
# you PRON
# seen VERB
# a DET
# doctor NOUN
# ? PUNCT
#
#  SPACE
# have AUX
# you PRON
# seen VERB
# a DET
# doctor NOUN
# ? PUNCT
# 	 SPACE
# i PRON
# 've AUX
# been AUX
# to ADP
# two NUM
# doctors NOUN
# . PUNCT
#
#  SPACE
# i PRON
# 've AUX
# been AUX
# to ADP
# two NUM
# doctors NOUN
# . PUNCT
# 	 SPACE
# and CCONJ
# they PRON
# could AUX
# n't PART
# fix VERB
# your PRON
# problem NOUN
# ? PUNCT
#
#  SPACE
# and CCONJ
# they PRON
# could AUX
# n't PART
# fix VERB
# your PRON
# problem NOUN
# ? PUNCT
# 	 SPACE
# they PRON
# both PRON
# said VERB
# i PRON
# have VERB
# to PART
# live VERB
# with ADP
# it PRON
# . PUNCT
#
#  SPACE
# they PRON
# both PRON
# said VERB
# i PRON
# have VERB
# to PART
# live VERB
# with ADP
# it PRON
# . PUNCT
# 	 SPACE
# or CCONJ
# you PRON
# can AUX
# stay VERB
# off ADP
# planes NOUN
# . PUNCT
#
#  SPACE
# did AUX
# you PRON
# see VERB
# the DET
# woman NOUN
# with ADP
# the DET
# new ADJ
# face NOUN
# ? PUNCT
# 	 SPACE
# did AUX
# she PRON
# get VERB
# a DET
# nice ADJ
# job NOUN
# ? PUNCT
#
#  SPACE
# did AUX
# she PRON
# get VERB
# a DET
# nice ADJ
# job NOUN
# ? PUNCT
# 	 SPACE
# she PRON
# got VERB
# an DET
# " PUNCT
# everything PRON
# " PUNCT
# job NOUN
# ! PUNCT
#
#  SPACE
# she PRON
# got VERB
# an DET
# " PUNCT
# everything PRON
# " PUNCT
# job NOUN
# ! PUNCT
# 	 SPACE
# what PRON
# do AUX
# you PRON
# mean VERB
# ? PUNCT
#
#  SPACE
# what PRON
# do AUX
# you PRON
# mean VERB
# ? PUNCT
# 	 SPACE
# a DET
# team NOUN
# of ADP
# doctors NOUN
# gave VERB
# her PRON
# a DET
# whole ADJ
# new ADJ
# face NOUN
# . PUNCT
#
#  SPACE
# a DET
# team NOUN
# of ADP
# doctors NOUN
# gave VERB
# her PRON
# a DET
# whole ADJ
# new ADJ
# face NOUN
# . PUNCT
# 	 SPACE
# why SCONJ
# did AUX
# they PRON
# do VERB
# that PRON
# ? PUNCT
#
#  SPACE
# why SCONJ
# did AUX
# they PRON
# do VERB
# that PRON
# ? PUNCT
# 	 SPACE
# a DET
# mad ADJ
# dog NOUN
# bit NOUN
# most ADJ
# of ADP
# her PRON
# face NOUN
# off ADP
# . PUNCT
#
#  SPACE
# a DET
# mad ADJ
# dog NOUN
# bit NOUN
# most ADJ
# of ADP
# her PRON
# face NOUN
# off ADV
# . PUNCT
# 	 SPACE
# oh INTJ
# , PUNCT
# that PRON
# 's AUX
# terrible ADJ
# . PUNCT
# what PRON
# does AUX
# she PRON
# look VERB
# like ADP
# now ADV
# ? PUNCT
#
#  SPACE
# oh INTJ
# , PUNCT
# that PRON
# 's AUX
# terrible ADJ
# . PUNCT
# what PRON
# does AUX
# she PRON
# look VERB
# like ADP
# now ADV
# ? PUNCT
# 	 SPACE
# her PRON
# face NOUN
# is AUX
# really ADV
# fat ADJ
# , PUNCT
# but CCONJ
# they PRON
# say VERB
# the DET
# swelling NOUN
# will AUX
# go VERB
# down ADV
# . PUNCT
#
#  SPACE
# her PRON
# face NOUN
# is AUX
# really ADV
# fat ADJ
# , PUNCT
# but CCONJ
# they PRON
# say VERB
# the DET
# swelling NOUN
# will AUX
# go VERB
# down ADV
# . PUNCT
# 	 SPACE
# and CCONJ
# then ADV
# will AUX
# she PRON
# look VERB
# normal ADJ
# again ADV
# ? PUNCT
#
#  SPACE
# and CCONJ
# then ADV
# will AUX
# she PRON
# look VERB
# normal ADJ
# again ADV
# ? PUNCT
# 	 SPACE
# i PRON
# guess VERB
# so ADV
# . PUNCT
#
#  SPACE
# i PRON
# guess VERB
# so ADV
# . PUNCT
# 	 SPACE
# god PROPN
# bless VERB
# modern ADJ
# medicine NOUN
# . PUNCT
#
#  SPACE
# there PRON
# 's VERB
# something PRON
# wrong ADJ
# with ADP
# my PRON
# right ADJ
# hand NOUN
# . PUNCT
# 	 SPACE
# what PRON
# 's AUX
# wrong ADJ
# with ADP
# it PRON
# ? PUNCT
#
#  SPACE
# what PRON
# 's AUX
# wrong ADJ
# with ADP
# it PRON
# ? PUNCT
# 	 SPACE
# it PRON
# aches VERB
# most ADJ
# of ADP
# the DET
# time NOUN
# . PUNCT
#
#  SPACE
# it PRON
# aches VERB
# most ADJ
# of ADP
# the DET
# time NOUN
# . PUNCT
# 	 SPACE
# what PRON
# do AUX
# you PRON
# think VERB
# it PRON
# is AUX
# ? PUNCT
#
#  SPACE
# what PRON
# do AUX
# you PRON
# think VERB
# it PRON
# is AUX
# ? PUNCT
# 	 SPACE
# i PRON
# do AUX
# n't PART
# know VERB
# . PUNCT
# i PRON
# think VERB
# it PRON
# 's AUX
# old ADJ
# age NOUN
# . PUNCT
#
#  SPACE
# i PRON
# do AUX
# n't PART
# know VERB
# . PUNCT
# i PRON
# think VERB
# it PRON
# 's AUX
# old ADJ
# age NOUN
# . PUNCT
# 	 SPACE
# if SCONJ
# it PRON
# 's AUX
# old ADJ
# age NOUN
# , PUNCT
# why SCONJ
# do AUX
# n't PART
# both PRON
# of ADP
# your PRON
# hands NOUN
# hurt VERB
# ? PUNCT
#
#  SPACE
# if SCONJ
# it PRON
# 's AUX
# old ADJ
# age NOUN
# , PUNCT
# why SCONJ
# do AUX
# n't PART
# both PRON
# of ADP
# your PRON
# hands NOUN
# hurt VERB
# ? PUNCT
# 	 SPACE
# that PRON
# 's AUX
# a DET
# good ADJ
# question NOUN
# . PUNCT
# maybe ADV
# it PRON
# 's AUX
# not PART
# old ADJ
# age NOUN
# . PUNCT
#
#  SPACE
# that PRON
# 's AUX
# a DET
# good ADJ
# question NOUN
# . PUNCT
# maybe ADV
# it PRON
# 's AUX
# not PART
# old ADJ
# age NOUN
# . PUNCT
# 	 SPACE
# are AUX
# you PRON
# right ADV
# - PUNCT
# handed ADJ
# ? PUNCT
#
#  SPACE
# are AUX
# you PRON
# right ADV
# - PUNCT
# handed ADJ
# ? PUNCT
# 	 SPACE
# yes INTJ
# . PUNCT
# all DET
# my PRON
# life NOUN
# . PUNCT
#
#  SPACE
# yes INTJ
# . PUNCT
# all DET
# my PRON
# life NOUN
# . PUNCT
# 	 SPACE
# you PRON
# 're AUX
# wearing VERB
# out ADP
# your PRON
# right ADJ
# hand NOUN
# . PUNCT
# stop VERB
# using VERB
# it PRON
# so ADV
# much ADV
# . PUNCT
#
#  SPACE
# you PRON
# 're AUX
# wearing VERB
# out ADP
# your PRON
# right ADJ
# hand NOUN
# . PUNCT
# stop VERB
# using VERB
# it PRON
# so ADV
# much ADV
# . PUNCT
# 	 SPACE
# but CCONJ
# i PRON
# do VERB
# all DET
# my PRON
# writing NOUN
# with ADP
# my PRON
# right ADJ
# hand NOUN
# . PUNCT
#
#  SPACE
# but CCONJ
# i PRON
# do VERB
# all DET
# my PRON
# writing NOUN
# with ADP
# my PRON
# right ADJ
# hand NOUN
# . PUNCT
# 	 SPACE
# start VERB
# typing VERB
# instead ADV
# . PUNCT
# that DET
# way NOUN
# your PRON
# left ADJ
# hand NOUN
# will AUX
# do VERB
# half DET
# the DET
# work NOUN
# . PUNCT

# %% [markdown]
# Importing libraries

# %%
import keras
import nltk
import pickle
import json
import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation
import random
import datetime
from googlesearch import *
import webbrowser
import requests

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
        w=nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w,intent['tag']))

        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words=[lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore]
words=sorted(list(set(words)))
classes=sorted(list(set(classes)))
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

training=[]
output_empty=[0]*len(classes)

# %%
for doc in documents:
    bag=[]
    pattern=doc[0]
    pattern=[ lemmatizer.lemmatize(word.lower()) for word in pattern ]

    for word in words:
        if word in pattern:
            bag.append(1)
        else:
            bag.append(0)
    output_row=list(output_empty)
    output_row[classes.index(doc[1])]=1

    training.append([bag,output_row])

random.shuffle(training)
training=np.array(training)
X_train=list(training[:,0])
y_train=list(training[:,1])
# Out:
# <ipython-input-116-28075235a86a>:17: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training=np.array(training)

# %% [markdown]
# Training the model using neural networks

# %%
model=Sequential()
model.add(Dense(128,activation='relu',input_shape=(len(X_train[0]),)))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(y_train[0]),activation='softmax'))

adam=keras.optimizers.Adam(0.001)
model.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['accuracy'])
weights=model.fit(np.array(X_train),np.array(y_train),epochs=200,batch_size=10,verbose=1)
model.save('mymodel.h5',weights)
# Out:
# Epoch 1/200
# 17/17 [==============================] - 5s 15ms/step - loss: 3.3998 - accuracy: 0.0359
# Epoch 2/200
# 17/17 [==============================] - 0s 13ms/step - loss: 3.3569 - accuracy: 0.0539
# Epoch 3/200
# 17/17 [==============================] - 0s 13ms/step - loss: 3.3272 - accuracy: 0.0838
# Epoch 4/200
# 17/17 [==============================] - 0s 18ms/step - loss: 3.2955 - accuracy: 0.1018
# Epoch 5/200
# 17/17 [==============================] - 0s 14ms/step - loss: 3.2290 - accuracy: 0.1437
# Epoch 6/200
# 17/17 [==============================] - 0s 13ms/step - loss: 3.1321 - accuracy: 0.2096
# Epoch 7/200
# 17/17 [==============================] - 0s 19ms/step - loss: 3.0169 - accuracy: 0.2156
# Epoch 8/200
# 17/17 [==============================] - 0s 10ms/step - loss: 2.8525 - accuracy: 0.2515
# Epoch 9/200
# 17/17 [==============================] - 0s 8ms/step - loss: 2.7192 - accuracy: 0.3054
# Epoch 10/200
# 17/17 [==============================] - 0s 10ms/step - loss: 2.6779 - accuracy: 0.2575
# Epoch 11/200
# 17/17 [==============================] - 0s 7ms/step - loss: 2.4893 - accuracy: 0.3293
# Epoch 12/200
# 17/17 [==============================] - 0s 8ms/step - loss: 2.3974 - accuracy: 0.3293
# Epoch 13/200
# 17/17 [==============================] - 0s 6ms/step - loss: 2.2704 - accuracy: 0.3353
# Epoch 14/200
# 17/17 [==============================] - 0s 7ms/step - loss: 2.2182 - accuracy: 0.3772
# Epoch 15/200
# 17/17 [==============================] - 0s 9ms/step - loss: 2.0762 - accuracy: 0.4371
# Epoch 16/200
# 17/17 [==============================] - 0s 6ms/step - loss: 1.9528 - accuracy: 0.4251
# Epoch 17/200
# 17/17 [==============================] - 0s 10ms/step - loss: 1.9346 - accuracy: 0.4311
# Epoch 18/200
# 17/17 [==============================] - 0s 10ms/step - loss: 1.8332 - accuracy: 0.5030
# Epoch 19/200
# 17/17 [==============================] - 0s 22ms/step - loss: 1.6182 - accuracy: 0.5389
# Epoch 20/200
# 17/17 [==============================] - 0s 9ms/step - loss: 1.7036 - accuracy: 0.5150
# Epoch 21/200
# 17/17 [==============================] - 0s 9ms/step - loss: 1.6066 - accuracy: 0.5509
# Epoch 22/200
# 17/17 [==============================] - 0s 10ms/step - loss: 1.4291 - accuracy: 0.5928
# Epoch 23/200
# 17/17 [==============================] - 0s 9ms/step - loss: 1.5110 - accuracy: 0.5868
# Epoch 24/200
# 17/17 [==============================] - 0s 10ms/step - loss: 1.3370 - accuracy: 0.6048
# Epoch 25/200
# 17/17 [==============================] - 0s 15ms/step - loss: 1.1924 - accuracy: 0.7006
# Epoch 26/200
# 17/17 [==============================] - 0s 16ms/step - loss: 1.2834 - accuracy: 0.5928
# Epoch 27/200
# 17/17 [==============================] - 0s 18ms/step - loss: 1.0895 - accuracy: 0.7126
# Epoch 28/200
# 17/17 [==============================] - 0s 21ms/step - loss: 1.1151 - accuracy: 0.6766
# Epoch 29/200
# 17/17 [==============================] - 0s 17ms/step - loss: 0.9973 - accuracy: 0.7126
# Epoch 30/200
# 17/17 [==============================] - 0s 21ms/step - loss: 0.9755 - accuracy: 0.7305
# Epoch 31/200
# 17/17 [==============================] - 0s 18ms/step - loss: 0.9563 - accuracy: 0.7186
# Epoch 32/200
# 17/17 [==============================] - 0s 16ms/step - loss: 0.9979 - accuracy: 0.7186
# Epoch 33/200
# 17/17 [==============================] - 0s 13ms/step - loss: 0.9391 - accuracy: 0.7246
# Epoch 34/200
# 17/17 [==============================] - 0s 12ms/step - loss: 0.8579 - accuracy: 0.7725
# Epoch 35/200
# 17/17 [==============================] - 0s 15ms/step - loss: 0.8630 - accuracy: 0.7425
# Epoch 36/200
# 17/17 [==============================] - 0s 9ms/step - loss: 0.8337 - accuracy: 0.7305
# Epoch 37/200
# 17/17 [==============================] - 0s 8ms/step - loss: 0.7977 - accuracy: 0.7545
# Epoch 38/200
# 17/17 [==============================] - 0s 14ms/step - loss: 0.7255 - accuracy: 0.7784
# Epoch 39/200
# 17/17 [==============================] - 0s 17ms/step - loss: 0.7191 - accuracy: 0.7844
# Epoch 40/200
# 17/17 [==============================] - 0s 14ms/step - loss: 0.6158 - accuracy: 0.8204
# Epoch 41/200
# 17/17 [==============================] - 0s 12ms/step - loss: 0.6448 - accuracy: 0.8024
# Epoch 42/200
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5320 - accuracy: 0.8383
# Epoch 43/200
# 17/17 [==============================] - 0s 13ms/step - loss: 0.6514 - accuracy: 0.8084
# Epoch 44/200
# 17/17 [==============================] - 0s 14ms/step - loss: 0.6452 - accuracy: 0.8144
# Epoch 45/200
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5668 - accuracy: 0.7904
# Epoch 46/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.6203 - accuracy: 0.7784
# Epoch 47/200
# 17/17 [==============================] - 0s 17ms/step - loss: 0.5168 - accuracy: 0.8323
# Epoch 48/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4802 - accuracy: 0.8802
# Epoch 49/200
# 17/17 [==============================] - 0s 11ms/step - loss: 0.5138 - accuracy: 0.8144
# Epoch 50/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5151 - accuracy: 0.8503
# Epoch 51/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5113 - accuracy: 0.8503
# Epoch 52/200
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4263 - accuracy: 0.8623
# Epoch 53/200
# 17/17 [==============================] - 0s 11ms/step - loss: 0.4275 - accuracy: 0.8743
# Epoch 54/200
# 17/17 [==============================] - 0s 9ms/step - loss: 0.4529 - accuracy: 0.8623
# Epoch 55/200
# 17/17 [==============================] - 0s 12ms/step - loss: 0.4465 - accuracy: 0.8503
# Epoch 56/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4215 - accuracy: 0.8743
# Epoch 57/200
# 17/17 [==============================] - 0s 11ms/step - loss: 0.4890 - accuracy: 0.8443
# Epoch 58/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4277 - accuracy: 0.8623
# Epoch 59/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.4221 - accuracy: 0.8563
# Epoch 60/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4352 - accuracy: 0.8503
# Epoch 61/200
# 17/17 [==============================] - 0s 11ms/step - loss: 0.3914 - accuracy: 0.8683
# Epoch 62/200
# 17/17 [==============================] - 0s 13ms/step - loss: 0.4445 - accuracy: 0.8802
# Epoch 63/200
# 17/17 [==============================] - 0s 11ms/step - loss: 0.3366 - accuracy: 0.9042
# Epoch 64/200
# 17/17 [==============================] - 0s 11ms/step - loss: 0.3911 - accuracy: 0.9042
# Epoch 65/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3877 - accuracy: 0.8922
# Epoch 66/200
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3584 - accuracy: 0.8623
# Epoch 67/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3076 - accuracy: 0.9042
# Epoch 68/200
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3897 - accuracy: 0.8623
# Epoch 69/200
# 17/17 [==============================] - 0s 13ms/step - loss: 0.3365 - accuracy: 0.8922
# Epoch 70/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3222 - accuracy: 0.8862
# Epoch 71/200
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3674 - accuracy: 0.8683
# Epoch 72/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3824 - accuracy: 0.8623
# Epoch 73/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3367 - accuracy: 0.8862
# Epoch 74/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3581 - accuracy: 0.9162
# Epoch 75/200
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3279 - accuracy: 0.8683
# Epoch 76/200
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2915 - accuracy: 0.9042
# Epoch 77/200
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3402 - accuracy: 0.8982
# Epoch 78/200
# 17/17 [==============================] - 0s 11ms/step - loss: 0.2872 - accuracy: 0.9341
# Epoch 79/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2911 - accuracy: 0.8982
# Epoch 80/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3048 - accuracy: 0.8922
# Epoch 81/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3235 - accuracy: 0.8862
# Epoch 82/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3088 - accuracy: 0.8862
# Epoch 83/200
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3207 - accuracy: 0.8683
# Epoch 84/200
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2434 - accuracy: 0.9102
# Epoch 85/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3072 - accuracy: 0.8862
# Epoch 86/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3130 - accuracy: 0.8982
# Epoch 87/200
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2858 - accuracy: 0.8802
# Epoch 88/200
# 17/17 [==============================] - 0s 12ms/step - loss: 0.2969 - accuracy: 0.9042
# Epoch 89/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.2641 - accuracy: 0.8982
# Epoch 90/200
# 17/17 [==============================] - 0s 12ms/step - loss: 0.2718 - accuracy: 0.9162
# Epoch 91/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.2857 - accuracy: 0.9042
# Epoch 92/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.2925 - accuracy: 0.8802
# Epoch 93/200
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2672 - accuracy: 0.8802
# Epoch 94/200
# 17/17 [==============================] - 0s 12ms/step - loss: 0.3184 - accuracy: 0.8743
# Epoch 95/200
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2600 - accuracy: 0.8922
# Epoch 96/200
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2018 - accuracy: 0.9222
# Epoch 97/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3321 - accuracy: 0.8922
# Epoch 98/200
# 17/17 [==============================] - 0s 11ms/step - loss: 0.2581 - accuracy: 0.9042
# Epoch 99/200
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2485 - accuracy: 0.8982
# Epoch 100/200
# 17/17 [==============================] - 0s 12ms/step - loss: 0.2504 - accuracy: 0.9162
# Epoch 101/200
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2626 - accuracy: 0.9102
# Epoch 102/200
# 17/17 [==============================] - 0s 13ms/step - loss: 0.2412 - accuracy: 0.9102
# Epoch 103/200
# 17/17 [==============================] - 0s 17ms/step - loss: 0.2449 - accuracy: 0.9222
# Epoch 104/200
# 17/17 [==============================] - 0s 12ms/step - loss: 0.2572 - accuracy: 0.9162
# Epoch 105/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.2693 - accuracy: 0.8982
# Epoch 106/200
# 17/17 [==============================] - 6s 400ms/step - loss: 0.2584 - accuracy: 0.8982
# Epoch 107/200
# 17/17 [==============================] - 2s 141ms/step - loss: 0.2159 - accuracy: 0.9162
# Epoch 108/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2650 - accuracy: 0.8743
# Epoch 109/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2381 - accuracy: 0.8922
# Epoch 110/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2374 - accuracy: 0.9222
# Epoch 111/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2530 - accuracy: 0.9162
# Epoch 112/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2172 - accuracy: 0.9042
# Epoch 113/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2142 - accuracy: 0.9222
# Epoch 114/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2119 - accuracy: 0.9281
# Epoch 115/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2282 - accuracy: 0.9042
# Epoch 116/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2620 - accuracy: 0.8802
# Epoch 117/200
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2215 - accuracy: 0.9162
# Epoch 118/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1799 - accuracy: 0.9581
# Epoch 119/200
# 17/17 [==============================] - 0s 10ms/step - loss: 0.2622 - accuracy: 0.8922
# Epoch 120/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1797 - accuracy: 0.9401
# Epoch 121/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2287 - accuracy: 0.9042
# Epoch 122/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2062 - accuracy: 0.9222
# Epoch 123/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1827 - accuracy: 0.9461
# Epoch 124/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2020 - accuracy: 0.9341
# Epoch 125/200
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2229 - accuracy: 0.9042
# Epoch 126/200
# 17/17 [==============================] - 0s 11ms/step - loss: 0.2067 - accuracy: 0.9102
# Epoch 127/200
# 17/17 [==============================] - 0s 12ms/step - loss: 0.2098 - accuracy: 0.9162
# Epoch 128/200
# 17/17 [==============================] - 0s 12ms/step - loss: 0.2324 - accuracy: 0.9042
# Epoch 129/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2356 - accuracy: 0.9162
# Epoch 130/200
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1979 - accuracy: 0.9341
# Epoch 131/200
# 17/17 [==============================] - 2s 137ms/step - loss: 0.1922 - accuracy: 0.9341
# Epoch 132/200
# 17/17 [==============================] - 5s 277ms/step - loss: 0.2035 - accuracy: 0.9102
# Epoch 133/200
# 17/17 [==============================] - 3s 180ms/step - loss: 0.2413 - accuracy: 0.9042
# Epoch 134/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1647 - accuracy: 0.9341
# Epoch 135/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2459 - accuracy: 0.9102
# Epoch 136/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1726 - accuracy: 0.9281
# Epoch 137/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2367 - accuracy: 0.9102
# Epoch 138/200
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1646 - accuracy: 0.9341
# Epoch 139/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2284 - accuracy: 0.8982
# Epoch 140/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1922 - accuracy: 0.9401
# Epoch 141/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1772 - accuracy: 0.9162
# Epoch 142/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1944 - accuracy: 0.9162
# Epoch 143/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2050 - accuracy: 0.9102
# Epoch 144/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1674 - accuracy: 0.9401
# Epoch 145/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2128 - accuracy: 0.9281
# Epoch 146/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1482 - accuracy: 0.9401
# Epoch 147/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1849 - accuracy: 0.9341
# Epoch 148/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2274 - accuracy: 0.9102
# Epoch 149/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1740 - accuracy: 0.9222
# Epoch 150/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1839 - accuracy: 0.9162
# Epoch 151/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1875 - accuracy: 0.9102
# Epoch 152/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1623 - accuracy: 0.9341
# Epoch 153/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2137 - accuracy: 0.8982
# Epoch 154/200
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1667 - accuracy: 0.9281
# Epoch 155/200
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1925 - accuracy: 0.9102
# Epoch 156/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1652 - accuracy: 0.9341
# Epoch 157/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1821 - accuracy: 0.9162
# Epoch 158/200
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1896 - accuracy: 0.9042
# Epoch 159/200
# 17/17 [==============================] - 2s 139ms/step - loss: 0.1886 - accuracy: 0.9281
# Epoch 160/200
# 17/17 [==============================] - 5s 320ms/step - loss: 0.1923 - accuracy: 0.9042
# Epoch 161/200
# 17/17 [==============================] - 2s 65ms/step - loss: 0.2690 - accuracy: 0.8922
# Epoch 162/200
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1312 - accuracy: 0.9461
# Epoch 163/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1282 - accuracy: 0.9521
# Epoch 164/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1638 - accuracy: 0.9281
# Epoch 165/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2005 - accuracy: 0.8922
# Epoch 166/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1500 - accuracy: 0.9401
# Epoch 167/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1545 - accuracy: 0.9521
# Epoch 168/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1957 - accuracy: 0.9341
# Epoch 169/200
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1774 - accuracy: 0.9042
# Epoch 170/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1489 - accuracy: 0.9461
# Epoch 171/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1323 - accuracy: 0.9222
# Epoch 172/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1610 - accuracy: 0.9341
# Epoch 173/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1654 - accuracy: 0.9281
# Epoch 174/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1650 - accuracy: 0.9102
# Epoch 175/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1788 - accuracy: 0.8922
# Epoch 176/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1965 - accuracy: 0.9042
# Epoch 177/200
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1788 - accuracy: 0.9162
# Epoch 178/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1624 - accuracy: 0.9281
# Epoch 179/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1477 - accuracy: 0.9461
# Epoch 180/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1436 - accuracy: 0.9461
# Epoch 181/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1452 - accuracy: 0.9461
# Epoch 182/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2190 - accuracy: 0.9162
# Epoch 183/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1308 - accuracy: 0.9581
# Epoch 184/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1578 - accuracy: 0.9281
# Epoch 185/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1416 - accuracy: 0.9281
# Epoch 186/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1134 - accuracy: 0.9701
# Epoch 187/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1451 - accuracy: 0.9401
# Epoch 188/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1284 - accuracy: 0.9461
# Epoch 189/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1408 - accuracy: 0.9162
# Epoch 190/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1256 - accuracy: 0.9521
# Epoch 191/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1691 - accuracy: 0.9341
# Epoch 192/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1710 - accuracy: 0.9162
# Epoch 193/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1916 - accuracy: 0.8862
# Epoch 194/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1551 - accuracy: 0.9222
# Epoch 195/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1535 - accuracy: 0.9341
# Epoch 196/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1633 - accuracy: 0.9281
# Epoch 197/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1799 - accuracy: 0.9401
# Epoch 198/200
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1949 - accuracy: 0.8982
# Epoch 199/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1961 - accuracy: 0.9281
# Epoch 200/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1443 - accuracy: 0.9222
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
def clean_up(sentence):
    sentence_words=nltk.word_tokenize(sentence)
    sentence_words=[ lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# %%
def create_bow(sentence,words):
    sentence_words=clean_up(sentence)
    bag=list(np.zeros(len(words)))

    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                bag[i] = 1
    return np.array(bag)

# %%
def predict_class(sentence,model):
    p=create_bow(sentence,words)
    res=model.predict(np.array([p]))[0]
    threshold=0.8
    results=[[i,r] for i,r in enumerate(res) if r>threshold]
    results.sort(key=lambda x: x[1],reverse=True)
    return_list=[]

    for result in results:
        return_list.append({'intent':classes[result[0]],'prob':str(result[1])})
    return return_list

# %%
def get_response(return_list,intents_json):

    if len(return_list)==0:
        tag='noanswer'
    else:
        tag=return_list[0]['intent']
    if tag=='datetime':
        print(time.strftime("%A"))
        print (time.strftime("%d %B %Y"))
        print (time.strftime("%H:%M:%S"))

    if tag=='google':
        query=input('Enter query...')
        chrome_path = r'C:\Program Files (x86)\Google\Chrome\Application\chrome.exe %s'
        for url in search(query, tld="co.in", num=1, stop = 1, pause = 2):
            webbrowser.open("https://google.com/search?q=%s" % query)
    if tag=='weather':
        api_key='987f44e8c16780be8c85e25a409ed07b'
        base_url = "http://api.openweathermap.org/data/2.5/weather?"
        city_name = input("Enter city name : ")
        complete_url = base_url + "appid=" + api_key + "&q=" + city_name
        response = requests.get(complete_url)
        x=response.json()
        print('Present temp.: ',round(x['main']['temp']-273,2),'celcius ')
        print('Feels Like:: ',round(x['main']['feels_like']-273,2),'celcius ')
        print(x['weather'][0]['main'])
    list_of_intents= intents_json['intents']
    for i in list_of_intents:
        if tag==i['tag'] :
          result= random.choice(i['responses'])
    return result

# %%
def response(text):
    return_list=predict_class(text,model)
    response=get_response(return_list,intents)
    return response

# %%
intents = json.loads(open("Intent.json").read())
words = pickle.load(open("words.pkl", "rb"))
classes = pickle.load(open("classes.pkl", "rb"))

def chatbot_response():
    msg = request.form["msg"]
    if msg.startswith('my name is'):
        name = msg[11:]
        ints = predict_class(msg, model)
        res1 = getResponse(ints, intents)
        res =res1.replace("{n}",name)
    elif msg.startswith('hi my name is'):
        name = msg[14:]
        ints = predict_class(msg, model)
        res1 = getResponse(ints, intents)
        res =res1.replace("{n}",name)
    else:
        ints = predict_class(msg, model)
        res = getResponse(ints, intents)
    return res



def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

def bow(sentence, words, show_details=True):
    sentence_words = clean_up_sentence(sentence)
    bag = [0] * len(words)
    for s in sentence_words:
        for i, w in enumerate(words):
            if w == s:
                bag[i] = 1
                if show_details:
                    print("found in bag: %s" % w)
    return np.array(bag)

def predict_class(sentence, model):
    p = bow(sentence, words, show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]["intent"]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents:
        if i["tag"] == tag:
            result = random.choice(i["responses"])
            break
    return result

# %%
while(1):
    x=input()
    if x.lower() in ['bye','goodbye','get lost','see you']:
        break
    else:
      print(response(x))


#Self learning
print('Help me Learn?')
tag=input('Please enter general category of your question  ')
flag=-1
for i in range(len(intents['intents'])):
    if tag.lower() in intents['intents'][i]['tag']:
        intents['intents'][i]['patterns'].append(input('Enter your message: '))
        intents['intents'][i]['responses'].append(input('Enter expected reply: '))
        flag=1

if flag==-1:

    intents['intents'].append (
        {'tag':tag,
         'patterns': [input('Please enter your message: ')],
         'responses': [input('Enter expected reply: ')]})

with open('intents.json','w') as outfile:
    outfile.write(json.dumps(intents,indent=4))
# Out:
# Hello
# 1/1 [==============================] - 0s 72ms/step
# Hola human, please tell me your GeniSys user
# I am Adam
# 1/1 [==============================] - 0s 21ms/step
# Cool! Hello <HUMAN>, what can I do for you?
# Thanks
# 1/1 [==============================] - 0s 20ms/step
# Happy to help!
# Goodbye
# Help me Learn?
# Please enter general category of your question  No
# Please enter your message: Bye
# Enter expected reply: Bye
